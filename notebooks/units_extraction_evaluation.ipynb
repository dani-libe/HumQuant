# %%
import os
import spacy
import pickle
from collections import namedtuple
import random
from cassis import load_typesystem, load_cas_from_xmi
import pandas as pd
import numpy as np

# %%
NumberAnnotation = namedtuple("NumberAnnotation", ["tokens", "span"])
AnnotationSpan = namedtuple("AnnotationSpan", ["begin", "end"])
SharedElement = namedtuple("SharedElement", ["ground", "predicted", "distance"])

# %%
def get_paths(test_set_metadata_path, rounds_path="../data/annotations_and_sources"):
  paths_data = {}

  with open(test_set_metadata_path, "rb") as f:
    test_set_metadata = pickle.load(f)

  for fname, annotator in test_set_metadata.items():
    paths_data[fname] = {}
    paths_data[fname]["annotations"] = f"{rounds_path}/annotation/{fname}.txt/{annotator}/{annotator}.xmi"
    paths_data[fname]["typesystem"] = f"{rounds_path}/annotation/{fname}.txt/{annotator}/TypeSystem.xml"
    paths_data[fname]["source"] = f"{rounds_path}/source/{fname}.txt"
    
  return paths_data

# %%
def get_source(fname, paths_data):
  with open(paths_data[fname]["source"], "r") as f:
    text = f.read()

  return text

# %%
def get_cas(paths):
  with open(paths["typesystem"], "rb") as f:
    typesystem = load_typesystem(f)
    
  with open(paths["annotations"], "rb") as f:
    cas = load_cas_from_xmi(f, typesystem=typesystem)

  return cas

# %%
def get_spacy_pipeline(enable_first_rule=True):
  improved_en_pipeline = spacy.load("en_core_web_sm")

  ruler = improved_en_pipeline.add_pipe("entity_ruler", config={"overwrite_ents": True})

  if enable_first_rule:
    ruler.add_patterns([{"label": "CARDINAL", "pattern": [{"LIKE_NUM": True, "OP": "+"}]}]) # Merge consecutive number tokens

  percentages_patterns = [
    [{'LIKE_NUM': True}, {'LOWER': {'IN': ['%', 'percent', 'percentage', 'percentages']}}],
    [{'LIKE_NUM': True}, {'LOWER': 'per'}, {'LOWER': 'cent'}]
  ]

  for pattern in percentages_patterns:
    ruler.add_patterns([{"label": "PERCENT", "pattern": pattern}])

  MONTHS = ('january', 'february', 'march', 'april', 'may', 'june', 'july', 'august', 'september', 'october', 'november', 'december', 'jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec')
  dates_patterns = [
    [{'LIKE_NUM': True}, {'LOWER': {'IN': MONTHS}}, {'LIKE_NUM': True}],
    [{'LIKE_NUM': True}, {'LOWER': 'of'}, {'LOWER': {'IN': MONTHS}}, {'LIKE_NUM': True}],
    [{'LOWER': {'IN': MONTHS}}, {'LIKE_NUM': True}],
    [{'LIKE_NUM': True}, {'LOWER': {'IN': MONTHS}}]
  ]

  for pattern in dates_patterns:
    ruler.add_patterns([{"label": "DATE", "pattern": pattern}])

  return improved_en_pipeline

# %%
# Baseline in which we use all the NUM tagged tokens as numbers
def extract_numbers_baseline(doc):
  numbers = []

  for token in doc:
    if token.pos_ == "NUM":
      span = AnnotationSpan(token.idx, token.idx + len(token.text))
      ann = NumberAnnotation(doc[token.i:token.i + 1], span)
      numbers.append([ann])
  
  return numbers

# %%
def extract_numbers(doc):
  numbers = []
  named_entities = doc.ents

  for ent in named_entities:
    # If the label is related to numerals and is only one token long or is made only of NUM-tagged tokens, I consider it a possible number
    if (ent.label_ == "PERCENT") or (ent.label_ in ["MONEY", "QUANTITY", "CARDINAL"] and (len(ent) == 1 or all(map(lambda t: t.pos_ == "NUM", ent)))):
      if ent.label_ != "MONEY" and ent.start - 1 >= 0 and doc[ent.start - 1:ent.start][0].pos_ != "PROPN":
        span = AnnotationSpan(ent[0].idx, ent[-1].idx + len(ent[-1].text))
        ann = NumberAnnotation(ent, span)
        numbers.append([ann])
    else:
      # If the label is not related to numerals or it is but is more than a token long (or is longer but is not made only of NUM-tagged tokens), I consider only the NUM-tagged tokens as possible numbers (and ig two or more of them are consecutive I consider them as a possible single number)
      if ent.label_ not in ["ORDINAL", "DATE", "TIME"]:
        nums_group = []
        for token in ent:
          if token.pos_ == "NUM" and token.i - 1 >= 0 and doc[token.i - 1:token.i][0].pos_ != "PROPN":
            token_span = AnnotationSpan(token.idx, token.idx + len(token.text))
            num_ann = NumberAnnotation(doc[token.i:token.i + 1], token_span)
            nums_group.append(num_ann)
          else:
            if len(nums_group) > 0:
              numbers.append(nums_group)
              nums_group = []
        
        if len(nums_group) > 0:
          numbers.append(nums_group)
  
  return numbers

# %% [markdown]
# ## Predict units

# %%
def predict_units(numbers, algorithm="humquant"):
  def search_for_tags(span, tags):
    tokens = []
    i = 0
    
    while i < len(span) and (span[i].pos_ not in tags or span[i].text in ["%", "percent"]):
      i += 1
      
    while i < len(span) and span[i].pos_ in tags:
      tokens.append((span[i], span[i].idx, span[i].idx + len(span[i].text)))
      i += 1

    return tokens

  # Get closest consecutive tokens that match specific constraints
  def get_cct(number_ann, algorithm=algorithm):
    if algorithm == "humquant":
      tokens_before_number = [elem for elem in number_ann.root.head.subtree if elem.i < number_ann.start]
      tokens_after_number = [elem for elem in number_ann.root.head.subtree if elem.i >= number_ann.end]

      # Currencies symbols are taken from https://github.com/vmasek/CurrencyConverter/blob/master/symbols.csv
      CURRENCIES_SYMBOLS = set(pd.read_csv("../data/currencies_symbols.csv", sep="\t")[["Code ISO 4217", "Symbol"]].values.ravel())
      relevant_tokens = []
      for token in tokens_before_number:
        if token.text.upper() in CURRENCIES_SYMBOLS:
          relevant_tokens.append((token, token.idx, token.idx + len(token.text)))
          break
      
      if len(relevant_tokens) == 0:
        relevant_tokens = search_for_tags(tokens_after_number, ["NOUN", "PROPN", "ADJ", "SYM"])

      return relevant_tokens
    elif algorithm == "b1":
      return [(elem, elem.idx, elem.idx + len(elem.text)) for elem in number_ann.root.head.subtree if not number_ann.start <= elem.i < number_ann.end]
    elif algorithm == "b2":
      return [(elem, elem.idx, elem.idx + len(elem.text)) for elem in number_ann.doc[number_ann.end:number_ann.end + 1]]
    
  units_data = {}

  for number_ann in numbers:
    pred_number = number_ann[0].tokens.doc.char_span(number_ann[0].span.begin, number_ann[-1].span.end)

    k = (pred_number.text, number_ann[0].span.begin, number_ann[-1].span.end)
    units_data[k] = get_cct(pred_number)


  return units_data

# %% [markdown]
# ## Get annotated units

# %%
def get_annotated_units(paths_data):
  ground_truth = {}
  get_main_info = lambda ground_elem: (ground_elem.get_covered_text(), pd.Interval(ground_elem.begin, ground_elem.end, closed="left"))

  for fname, paths in paths_data.items():
    ground_truth[fname] = {}

    cas = get_cas(paths)

    ground_numbers = [ann for ann in cas.select("custom.Span") if ann.label == "Number"]
    ground_units = [(ann.Governor, ann.Dependent) for ann in cas.select("custom.Relation") if ann.Governor.label == "Number" and ann.Dependent.label == "Unit"]

    for ground_number in ground_numbers:
      ground_n = get_main_info(ground_number)
      ground_truth[fname][ground_n] = []

    for ground_number, ground_unit in ground_units:
      ground_n = get_main_info(ground_number)
      ground_u = get_main_info(ground_unit)
      ground_truth[fname][ground_n].append(ground_u)

  return ground_truth

# %% [markdown]
# ## Get predicted units

# %%
def get_shared_extracted_numbers(extracted_numbers, annotated_numbers):
  shared_numbers = []

  for extracted_number in extracted_numbers:
    extracted_number_span = pd.Interval(extracted_number[0].span.begin, extracted_number[-1].span.end, closed="left")

    for annotated_number in annotated_numbers:
      if extracted_number_span.overlaps(annotated_number[1]):
        shared_numbers.append((extracted_number, annotated_number))

  return shared_numbers

# %%
def get_predicted_units(paths_data, en_pipeline, annotated_numbers_by_fname, extract_numbers_alg=extract_numbers, consider_only_matching_numbers=True, save_numbers_wo_units=False, algorithm="humquant"):
  pred_units = {}
  shared_numbers_ground = {}

  for fname in paths_data.keys():
    source_text = get_source(fname, paths_data)
    source_doc = en_pipeline(source_text)
    extracted_numbers = extract_numbers_alg(source_doc)

    if consider_only_matching_numbers:
      shared_numbers = get_shared_extracted_numbers(extracted_numbers, annotated_numbers_by_fname[fname])
      extracted_numbers = [elem[0] for elem in shared_numbers] # I take only the predicted version of each shared number
      shared_numbers_ground[fname] = [elem[1] for elem in shared_numbers]

    pred_units_data = predict_units(extracted_numbers, algorithm=algorithm)

    pred_units[fname] = {}
    for num, unit in pred_units_data.items():
      pred_num = (num[0], pd.Interval(num[1], num[2], closed="left"))

      if len(unit) > 0:
        pred_unit = (unit[0][0].doc.text[unit[0][1]:unit[-1][2]], pd.Interval(unit[0][1], unit[-1][2], closed="left"))
        
        try:
          pred_units[fname][pred_num].append(pred_unit)
        except KeyError:
          pred_units[fname][pred_num] = [pred_unit]
      else:
        if save_numbers_wo_units:
          pred_units[fname][pred_num] = []

  return pred_units, shared_numbers_ground

# %%
def get_rels_by_fname(full_raw_data):
  rels = {}

  for fname, anns in full_raw_data.items():
    rels[fname] = []

    for num_ann, unit_anns in anns.items():
      if len(unit_anns) > 0:
        for unit_ann in unit_anns:
          rels[fname].append((num_ann, unit_ann))
      else:
        rels[fname].append((num_ann, None))

  return rels

# %%
def get_distance(pred, ground):
  def get_intersection(fst, snd):
    if snd.left > fst.right or fst.left > snd.right:
      return None # It's not needed because this function will be called only in overlapping scenarios
    else:
      overlap_l = max(fst.left, snd.left)
      overlap_r = min(fst.right, snd.right)

    return pd.Interval(overlap_l, overlap_r, closed="left")
  
  intersection = get_intersection(pred[1], ground[1])
  diff = (pred[1].right - pred[1].left) + (ground[1].right - ground[1].left) - 2 * (intersection.right - intersection.left)

  return diff

# %%
def custom_intersection_for_docs_sets(ground_rels, pred_rels):
  intersection = set()
  already_matched_ground_numbers = set()

  for pred_rel_num, pred_rel_unit in pred_rels:
    for ground_rel_num, ground_rel_unit in ground_rels:
      if pred_rel_num[1].overlaps(ground_rel_num[1]):
        if ground_rel_num not in already_matched_ground_numbers:
          if (ground_rel_unit is None and pred_rel_unit is None) or (pred_rel_unit is not None and ground_rel_unit is not None and pred_rel_unit[1].overlaps(ground_rel_unit[1])):
            if ground_rel_unit is None or pred_rel_unit is None:
              distance = 0
            else:
              distance = get_distance(pred_rel_unit, ground_rel_unit)

            intersection.add(SharedElement((ground_rel_num, ground_rel_unit), (pred_rel_num, pred_rel_unit), distance))
            already_matched_ground_numbers.add(ground_rel_num)
            break

  return intersection

# %% [markdown]
# ## Evaluation over the entire set

# %%
def pretty_print(to_print):
  final_str = ""

  for elem in to_print:
    if not isinstance(elem, SharedElement):
      num_data, unit_data = elem

      final_str += f"{num_data[0]} [B: {num_data[1].left} - E: {num_data[1].right}]\n"
      
      if unit_data is None:
        final_str += "  NO_UNIT\n"
      else:
        final_str += f"  {unit_data[0]} [B: {unit_data[1].left} - E: {unit_data[1].right}]\n"
    else:
      g_num_data, g_unit_data = elem.ground
      p_num_data, p_unit_data = elem.predicted

      final_str += f"G: {g_num_data[0]} [B: {g_num_data[1].left} - E: {g_num_data[1].right}]\n"
      final_str += f"P: {p_num_data[0]} [B: {p_num_data[1].left} - E: {p_num_data[1].right}]\n"

      final_str += f"  === distance: {elem.distance} ===\n"

      # IMPORTANT: refactoring del codice, così è pieno di ripetizioni inutili
      if g_unit_data is None:
        final_str += "  NO_UNIT\n"
      else:
        final_str += f"  G: {g_unit_data[0]} [B: {g_unit_data[1].left} - E: {g_unit_data[1].right}]\n"

      if p_unit_data is None:
        final_str += "  NO_UNIT\n"
      else:
        final_str += f"  P: {p_unit_data[0]} [B: {p_unit_data[1].left} - E: {p_unit_data[1].right}]\n"

    final_str += "\n"

  return final_str

# %% [markdown]
# # Evaluation

# %% [markdown]
# Variables:

# %%
TEST_SET_METADATA_PATH = "../data/test_set_metadata.pkl"
ALGORITHM = "humquant" # One of "humquant" (use our approach), "b1" (use the entire subtree of each extracted number as predicted unit), "b2" (as next consecutive token as predicted unit)
ENABLE_FIRST_RULE = True # Enable the concatenation of consecutive tokens
CONSIDER_ONLY_MATCHING_NUMBERS = False # When evaluating, consider only the predicted numbers (and their units) as the ground truth
SAVE_NUMBERS_WO_UNITS = False # Save predicted numbers that are not linked to a predicted unit
USE_NUMBER_EXTRACTOR_BASELINE = False # Use the baseline for the extraction of numbers

# %% [markdown]
# Code:

# %%
paths = get_paths(TEST_SET_METADATA_PATH)
en_pipeline = get_spacy_pipeline(enable_first_rule=ENABLE_FIRST_RULE)
annotated_units = get_annotated_units(paths)
annotated_numbers_by_fname = {fname: [num_ann for num_ann, _ in anns.items()] for fname, anns in annotated_units.items()}

extract_numbers_alg = extract_numbers
if USE_NUMBER_EXTRACTOR_BASELINE:
  extract_numbers_alg = extract_numbers_baseline

predicted_units, shared_numbers_ground = get_predicted_units(paths, en_pipeline, annotated_numbers_by_fname, extract_numbers_alg=extract_numbers_alg, consider_only_matching_numbers=CONSIDER_ONLY_MATCHING_NUMBERS, save_numbers_wo_units=SAVE_NUMBERS_WO_UNITS, algorithm=ALGORITHM)

ground_anns_reshaped = get_rels_by_fname(annotated_units)
pred_anns_reshaped = get_rels_by_fname(predicted_units)

assert ground_anns_reshaped.keys() == pred_anns_reshaped.keys()

avg_ps = []
avg_rs = []
avg_f1s = []
diffs = {}

final_str = ""
for fname in ground_anns_reshaped.keys():
  if CONSIDER_ONLY_MATCHING_NUMBERS:
    relevant_docs = [elem for elem in ground_anns_reshaped[fname] if elem[0] in shared_numbers_ground[fname]]
  else:
    relevant_docs = ground_anns_reshaped[fname]
  
  retrieved_docs = pred_anns_reshaped[fname]

  shared_docs = custom_intersection_for_docs_sets(relevant_docs, retrieved_docs)

  if len(relevant_docs) == 0 and len(retrieved_docs) == 0:
    precision = 1.
    recall = 1.
    f1_score = 1.
  else:
    try:
      precision = len(shared_docs) / len(set(retrieved_docs))
    except ZeroDivisionError:
      precision = 0.

    try:
      recall = len(shared_docs) / len(set(relevant_docs))
    except ZeroDivisionError:
      recall = 0.

    try:
      f1_score = (2 * precision * recall) / (precision + recall)
    except ZeroDivisionError:
      f1_score = 0.

  final_str += f"Excerpt: {fname}\n\n"
  final_str += f"=== RELEVANT DOCS ({len(relevant_docs)}) ===\n"
  final_str += pretty_print(relevant_docs)
  final_str += f"=== RETURNED DOCS ({len(retrieved_docs)}) ===\n"
  final_str += pretty_print(retrieved_docs)
  final_str += f"=== SHARED DOCS ({len(shared_docs)}) ===\n"
  final_str += pretty_print(shared_docs)
  final_str += f"P: {precision}, R: {recall}, F1: {f1_score}\n"
  final_str += "#" * 50 + "\n\n"
      
  # Average of differences for each excerpt (by considering only instances that partially match)
  if len(shared_docs) > 0:
    partial_matches_dists = [elem.distance for elem in shared_docs if elem.distance > 0]
    if len(partial_matches_dists) > 0:
      diffs[fname] = sum(partial_matches_dists) / len(partial_matches_dists)

  avg_ps.append(precision)
  avg_rs.append(recall)
  avg_f1s.append(f1_score)

avg_p, std_p = np.mean(avg_ps), np.std(avg_ps)
avg_r, std_r = np.mean(avg_rs), np.std(avg_rs)
avg_f1, std_f1 = np.mean(avg_f1s), np.std(avg_f1s)

avg_diff = sum(diffs.values()) / len(diffs.keys())

print(f"Avg P: {avg_p} (std: {std_p})", f"Avg R: {avg_r} (std: {std_r})", f"Avg F1: {avg_f1} (std: {std_f1})", sep="\n")
print(f"Average difference: {avg_diff} chars")
# Out:
# Avg P: 0.630811087061087 (std: 0.31507495045474854)
# Avg R: 0.6233820937207225 (std: 0.3308537470149872)
# Avg F1: 0.6037998871117858 (std: 0.30457789068400304)
# Average difference: 14.266600529100531 chars

# %%
print(final_str)
# Out:
# Excerpt: a2_6051
#
# === RELEVANT DOCS (3) ===
# 1.1 million [B: 270 - E: 281]
#   people [B: 282 - E: 288]
#
# 378,000 [B: 299 - E: 306]
#   children [B: 311 - E: 319]
#
# 307,000 [B: 324 - E: 331]
#   women [B: 336 - E: 341]
#
# === RETURNED DOCS (3) ===
# two [B: 95 - E: 98]
#   household multi-sectoral needs assessments [B: 99 - E: 141]
#
# 1.1 million [B: 270 - E: 281]
#   people [B: 282 - E: 288]
#
# 378,000 [B: 299 - E: 306]
#   children [B: 311 - E: 319]
#
# === SHARED DOCS (2) ===
# G: 378,000 [B: 299 - E: 306]
# P: 378,000 [B: 299 - E: 306]
#   === distance: 0 ===
#   G: children [B: 311 - E: 319]
#   P: children [B: 311 - E: 319]
#
# G: 1.1 million [B: 270 - E: 281]
# P: 1.1 million [B: 270 - E: 281]
#   === distance: 0 ===
#   G: people [B: 282 - E: 288]
#   P: people [B: 282 - E: 288]
#
# P: 0.6666666666666666, R: 0.6666666666666666, F1: 0.6666666666666666
# ##################################################
#
# Excerpt: a2_186485
#
# === RELEVANT DOCS (4) ===
# 84% [B: 104 - E: 107]
#   women [B: 111 - E: 116]
#
# 5% [B: 170 - E: 172]
#   NO_UNIT
#
# 35% [B: 230 - E: 233]
#   women [B: 237 - E: 242]
#
# 50% [B: 282 - E: 285]
#   men [B: 289 - E: 292]
#
# === RETURNED DOCS (4) ===
# 84% [B: 104 - E: 107]
#   women [B: 111 - E: 116]
#
# 5% [B: 170 - E: 172]
#   gender gap [B: 173 - E: 183]
#
# 35% [B: 230 - E: 233]
#   women [B: 237 - E: 242]
#
# 50% [B: 282 - E: 285]
#   men10 [B: 289 - E: 294]
#
# === SHARED DOCS (3) ===
# G: 35% [B: 230 - E: 233]
# P: 35% [B: 230 - E: 233]
#   === distance: 0 ===
#   G: women [B: 237 - E: 242]
#   P: women [B: 237 - E: 242]
#
# G: 50% [B: 282 - E: 285]
# P: 50% [B: 282 - E: 285]
#   === distance: 2 ===
#   G: men [B: 289 - E: 292]
#   P: men10 [B: 289 - E: 294]
#
# G: 84% [B: 104 - E: 107]
# P: 84% [B: 104 - E: 107]
#   === distance: 0 ===
#   G: women [B: 111 - E: 116]
#   P: women [B: 111 - E: 116]
#
# P: 0.75, R: 0.75, F1: 0.75
# ##################################################
#
# Excerpt: a2_26483
#
# === RELEVANT DOCS (2) ===
# 60% [B: 88 - E: 91]
#   NO_UNIT
#
# 70% [B: 121 - E: 124]
#   NO_UNIT
#
# === RETURNED DOCS (0) ===
# === SHARED DOCS (0) ===
# P: 0.0, R: 0.0, F1: 0.0
# ##################################################
#
# Excerpt: a3_223620
#
# === RELEVANT DOCS (2) ===
# 10 percent [B: 79 - E: 89]
#   livestock production [B: 30 - E: 50]
#
# 60 percent [B: 121 - E: 131]
#   livestock production [B: 30 - E: 50]
#
# === RETURNED DOCS (2) ===
# 10 percent [B: 79 - E: 89]
#   same period [B: 97 - E: 108]
#
# 60 percent [B: 121 - E: 131]
#   levels [B: 135 - E: 141]
#
# === SHARED DOCS (0) ===
# P: 0.0, R: 0.0, F1: 0.0
# ##################################################
#
# Excerpt: a3_186686
#
# === RELEVANT DOCS (1) ===
# 42 per cent [B: 43 - E: 54]
#   households [B: 58 - E: 68]
#
# === RETURNED DOCS (2) ===
# 42 per cent [B: 43 - E: 54]
#   households [B: 58 - E: 68]
#
# one [B: 112 - E: 115]
#   household member [B: 116 - E: 132]
#
# === SHARED DOCS (1) ===
# G: 42 per cent [B: 43 - E: 54]
# P: 42 per cent [B: 43 - E: 54]
#   === distance: 0 ===
#   G: households [B: 58 - E: 68]
#   P: households [B: 58 - E: 68]
#
# P: 0.5, R: 1.0, F1: 0.6666666666666666
# ##################################################
#
# Excerpt: a1_22580
#
# === RELEVANT DOCS (7) ===
# 16 [B: 43 - E: 45]
#   states in Nigeria [B: 46 - E: 63]
#
# 213 [B: 171 - E: 174]
#   confirmed cases [B: 175 - E: 190]
#
# 42 [B: 210 - E: 212]
#   deaths [B: 213 - E: 219]
#
# third [B: 261 - E: 266]
#   total cases [B: 274 - E: 285]
#
# Four [B: 368 - E: 372]
#   health workers [B: 373 - E: 387]
#
# 12 [B: 450 - E: 452]
#   cases [B: 453 - E: 458]
#
# two [B: 533 - E: 536]
#   deaths [B: 537 - E: 543]
#
# === RETURNED DOCS (7) ===
# 16 [B: 43 - E: 45]
#   states [B: 46 - E: 52]
#
# 213 [B: 171 - E: 174]
#   cases [B: 185 - E: 190]
#
# 42 [B: 210 - E: 212]
#   deaths [B: 213 - E: 219]
#
# third [B: 261 - E: 266]
#   total cases [B: 274 - E: 285]
#
# Four [B: 368 - E: 372]
#   health workers [B: 373 - E: 387]
#
# 12 [B: 450 - E: 452]
#   cases [B: 453 - E: 458]
#
# two [B: 533 - E: 536]
#   deaths [B: 537 - E: 543]
#
# === SHARED DOCS (7) ===
# G: 12 [B: 450 - E: 452]
# P: 12 [B: 450 - E: 452]
#   === distance: 0 ===
#   G: cases [B: 453 - E: 458]
#   P: cases [B: 453 - E: 458]
#
# G: two [B: 533 - E: 536]
# P: two [B: 533 - E: 536]
#   === distance: 0 ===
#   G: deaths [B: 537 - E: 543]
#   P: deaths [B: 537 - E: 543]
#
# G: Four [B: 368 - E: 372]
# P: Four [B: 368 - E: 372]
#   === distance: 0 ===
#   G: health workers [B: 373 - E: 387]
#   P: health workers [B: 373 - E: 387]
#
# G: third [B: 261 - E: 266]
# P: third [B: 261 - E: 266]
#   === distance: 0 ===
#   G: total cases [B: 274 - E: 285]
#   P: total cases [B: 274 - E: 285]
#
# G: 42 [B: 210 - E: 212]
# P: 42 [B: 210 - E: 212]
#   === distance: 0 ===
#   G: deaths [B: 213 - E: 219]
#   P: deaths [B: 213 - E: 219]
#
# G: 213 [B: 171 - E: 174]
# P: 213 [B: 171 - E: 174]
#   === distance: 10 ===
#   G: confirmed cases [B: 175 - E: 190]
#   P: cases [B: 185 - E: 190]
#
# G: 16 [B: 43 - E: 45]
# P: 16 [B: 43 - E: 45]
#   === distance: 11 ===
#   G: states in Nigeria [B: 46 - E: 63]
#   P: states [B: 46 - E: 52]
#
# P: 1.0, R: 1.0, F1: 1.0
# ##################################################
#
# Excerpt:
#   boys/girls [B: 396 - E: 406]
#
# === RETURNED DOCS (5) ===
# 3 4 [B: 199 - E: 202]
#   experience [B: 209 - E: 219]
#
# 15,000 [B: 331 - E: 337]
#   host community [B: 338 - E: 352]
#
# 800 [B: 368 - E: 371]
#   migrant children [B: 372 - E: 388]
#
# 2019 [B: 616 - E: 620]
#   - [B: 620 - E: 621]
#
# first [B: 801 - E: 806]
#   draft [B: 807 - E: 812]
#
# === SHARED DOCS (2) ===
# G: 15,000 [B: 331 - E: 337]
# P: 15,000 [B: 331 - E: 337]
#   === distance: 0 ===
#   G: host community [B: 338 - E: 352]
#   P: host community [B: 338 - E: 352]
#
# G: 800 [B: 368 - E: 371]
# P: 800 [B: 368 - E: 371]
#   === distance: 0 ===
#   G: migrant children [B: 372 - E: 388]
#   P: migrant children [B: 372 - E: 388]
#
# P: 0.4, R: 0.6666666666666666, F1: 0.5
# ##################################################
#
# Excerpt: a3_104965
#
# === RELEVANT DOCS (3) ===
# two [B: 138 - E: 141]
#   month [B: 142 - E: 147]
#
# 7 [B: 320 - E: 321]
#   month [B: 322 - E: 327]
#
# 25,913 [B: 452 - E: 458]
#   cases pending adjudication [B: 422 - E: 448]
#
# === RETURNED DOCS (2) ===
# two [B: 138 - E: 141]
#   month [B: 142 - E: 147]
#
# 7 [B: 320 - E: 321]
#   month [B: 322 - E: 327]
#
# === SHARED DOCS (2) ===
# G: 7 [B: 320 - E: 321]
# P: 7 [B: 320 - E: 321]
#   === distance: 0 ===
#   G: month [B: 322 - E: 327]
#   P: month [B: 322 - E: 327]
#
# G: two [B: 138 - E: 141]
# P: two [B: 138 - E: 141]
#   === distance: 0 ===
#   G: month [B: 142 - E: 147]
#   P: month [B: 142 - E: 147]
#
# P: 1.0, R: 0.6666666666666666, F1: 0.8
# ##################################################
#
# Excerpt: a3_385303
#
# === RELEVANT DOCS (2) ===
# two [B: 309 - E: 312]
#   locationss [B: 313 - E: 323]
#
# 140 [B: 645 - E: 648]
#   kilometer [B: 649 - E: 658]
#
# === RETURNED DOCS (2) ===
# two [B: 309 - E: 312]
#   locationss [B: 313 - E: 323]
#
# 140 [B: 645 - E: 648]
#   kilometer [B: 649 - E: 658]
#
# === SHARED DOCS (2) ===
# G: 140 [B: 645 - E: 648]
# P: 140 [B: 645 - E: 648]
#   === distance: 0 ===
#   G: kilometer [B: 649 - E: 658]
#   P: kilometer [B: 649 - E: 658]
#
# G: two [B: 309 - E: 312]
# P: two [B: 309 - E: 312]
#   === distance: 0 ===
#   G: locationss [B: 313 - E: 323]
#   P: locationss [B: 313 - E: 323]
#
# P: 1.0, R: 1.0, F1: 1.0
# ##################################################
#
# Excerpt: a2_75113
#
# === RELEVANT DOCS (0) ===
# === RETURNED DOCS (2) ===
# one [B: 73 - E: 76]
#   measures [B: 84 - E: 92]
#
# one [B: 309 - E: 312]
#   visa [B: 330 - E: 334]
#
# === SHARED DOCS (0) ===
# P: 0.0, R: 0.0, F1: 0.0
# ##################################################
#
# Excerpt: a1a3_25314
#
# === RELEVANT DOCS (23) ===
# twenty-three [B: 32 - E: 44]
#   G: death [B: 1060 - E: 1065]
#   P: death [B: 1060 - E: 1065]
#
# G: one [B: 699 - E: 702]
# P: one [B: 699 - E: 702]
#   === distance: 0 ===
#   G: death [B: 703 - E: 708]
#   P: death [B: 703 - E: 708]
#
# G: one [B: 164 - E: 167]
# P: one [B: 164 - E: 167]
#   === distance: 0 ===
#   G: death [B: 168 - E: 173]
#   P: death [B: 168 - E: 173]
#
# G: two [B: 124 - E: 127]
# P: two [B: 124 - E: 127]
#   === distance: 0 ===
#   G: deaths [B: 128 - E: 134]
#   P: deaths [B: 128 - E: 134]
#
# G: two [B: 587 - E: 590]
# P: two [B: 587 - E: 590]
#   === distance: 0 ===
#   G: deaths [B: 591 - E: 597]
#   P: deaths [B: 591 - E: 597]
#
# G: one [B: 1131 - E: 1134]
# P: one [B: 1131 - E: 1134]
#   === distance: 0 ===
#   G: death [B: 1135 - E: 1140]
#   P: death [B: 1135 - E: 1140]
#
# P: 0.9090909090909091, R: 0.8695652173913043, F1: 0.888888888888889
# ##################################################
#
# Excerpt: a2_62075
#
# === RELEVANT DOCS (4) ===
# 60 percent [B: 93 - E: 103]
#   NO_UNIT
#
# eleven [B: 573 - E: 579]
#   years [B: 580 - E: 585]
#
# 70 percent [B: 659 - E: 669]
#   NO_UNIT
#
# 80 percent [B: 885 - E: 895]
#   households [B: 899 - E: 909]
#
# === RETURNED DOCS (2) ===
# eleven [B: 573 - E: 579]
#   years [B: 580 - E: 585]
#
# 80 percent [B: 885 - E: 895]
#   households food insecure [B: 899 - E: 923]
#
# === SHARED DOCS (2) ===
# G: eleven [B: 573 - E: 579]
# P: eleven [B: 573 - E: 579]
#   === distance: 0 ===
#   G: years [B: 580 - E: 585]
#   P: years [B: 580 - E: 585]
#
# G: 80 percent [B: 885 - E: 895]
# P: 80 percent [B: 885 - E: 895]
#   === distance: 14 ===
#   G: households [B: 899 - E: 909]
#   P: households food insecure [B: 899 - E: 923]
#
# P: 1.0, R: 0.5, F1: 0.6666666666666666
# ##################################################
#
# Excerpt: a2_357797
#
# === RELEVANT DOCS (7) ===
# 115, 051 [B: 380 - E: 388]
#   children [B: 389 - E: 397]
#
# 59,510 [B: 406 - E: 412]
#   girls [B: 399 - E: 404]
#
# 55,541 [B: 420 - E: 426]
#   boys [B: 414 - E: 418]
#
# 112, 544 [B: 503 - E: 511]
#   children [B: 512 - E: 520]
#
# 1004 [B: 582 - E: 586]
#   unaccompanied, separated and children [B: 587 - E: 624]
#
# 1, 885 [B: 705 - E: 711]
#   child beneficiaries [B: 712 - E: 731]
#
# 23, 155 [B: 772 - E: 779]
#   children/adolescents [B: 780 - E: 800]
#
# === RETURNED DOCS (9) ===
# first [B: 29 - E: 34]
#   quarter [B: 35 - E: 42]
#
# 115 [B: 380 - E: 383]
#   children [B: 389 - E: 397]
#
# 59,510 [B: 406 - E: 412]
#   boys [B: 414 - E: 418]
#
# 112 [B: 503 - E: 506]
#   children [B: 512 - E: 520]
#
# 544 [B: 508 - E: 511]
#   children [B: 512 - E: 520]
#
# G: 1, 411 [B: 225 - E: 231]
# P: 1 [B: 225 - E: 226]
#   === distance: 0 ===
#   G: boys [B: 232 - E: 236]
#   P: boys [B: 232 - E: 236]
#
# G: 2,461 [B: 212 - E: 217]
# P: 2,461 [B: 212 - E: 217]
#   === distance: 0 ===
#   G: women [B: 218 - E: 223]
#   P: women [B: 218 - E: 223]
#
# G: 1,260 [B: 130 - E: 135]
# P: 1,260 [B: 130 - E: 135]
#   === distance: 0 ===
#   G: households [B: 136 - E: 146]
#   P: households [B: 136 - E: 146]
#
# G: 10 [B: 655 - E: 657]
# P: 10 [B: 655 - E: 657]
#   === distance: 21 ===
#   G: jingles per day by ABC Radio [B: 658 - E: 686]
#   P: jingles [B: 658 - E: 665]
#
# G: 5 [B: 688 - E: 689]
# P: 5 [B: 688 - E: 689]
#   === distance: 22 ===
#   G: jingles per day by Pulaako FM [B: 690 - E: 719]
#   P: jingles [B: 690 - E: 697]
#
# G: 10 [B: 572 - E: 574]
# P: 10 [B: 572 - E: 574]
#   === distance: 36 ===
#   G: jingles per day in Radio Nigeria Fombina FM [B: 575 - E: 618]
#   P: jingles [B: 575 - E: 582]
#
# P: 0.8461538461538461, R: 1.0, F1: 0.9166666666666666
# ##################################################
#
# Excerpt: a1_241888
#
# === RELEVANT DOCS (7) ===
# 3,900 [B: 274 - E: 279]
#   USD/LBP [B: 266 - E: 273]
#
# half [B: 288 - E: 292]
#   retailers [B: 56 - E: 65]
#
# 8,000 [B: 331 - E: 336]
#   USD/LBP [B: 323 - E: 330]
#
# Eighty-four percent [B: 394 - E: 413]
#   retailers [B: 56 - E: 65]
#
# 3,900 [B: 547 - E: 552]
#   LBP [B: 544 - E: 547]
#
# 3,900 [B: 547 - E: 552]
#   /USD [B: 552 - E: 556]
#
# two percent [B: 682 - E: 693]
#   NO_UNIT
#
# === RETURNED DOCS (2) ===
# four percent [B: 401 - E: 413]
#   able [B: 419 - E: 423]
#
# two percent [B: 682 - E: 693]
#   full ordered quantities [B: 710 - E: 733]
#
# === SHARED DOCS (0) ===
# P: 0.0, R: 0.0, F1: 0.0
# ##################################################
#
# Excerpt: a2a3_310409
#
# === RELEVANT DOCS (3) ===
# 80 percent [B: 123 - E: 133]
#   Rohingya households [B: 137 - E: 156]
#
# 40 percent [B: 161 - E: 171]
#   host community households [B: 175 - E: 200]
#
# 7 percent [B: 300 - E: 309]
#   NO_UNIT
#
# === RETURNED DOCS (5) ===
# 2019 [B: 108 - E: 112]
#   findings [B: 113 - E: 121]
#
# 80 percent [B: 123 - E: 133]
#   Rohingya households [B: 137 - E: 156]
#
# 40 percent [B: 161 - E: 171]
#   host community households [B: 175 - E: 200]
#
# 7 percent [B: 300 - E: 309]
#   increase [B: 310 - E: 318]
#
# 19 [B: 466 - E: 468]
#   Trends [B: 469 - E: 475]
#
# === SHARED DOCS (2) ===
# G: 40 percent [B: 161 - E: 171]
# P: 40 percent [B: 161 - E: 171]
#   === distance: 0 ===
#   G: host community households [B: 175 - E: 200]
#   P: jobs [B: 117 - E: 121]
#
# P: 0.4, R: 0.25, F1: 0.3076923076923077
# ##################################################
#
# Excerpt: a2_11626
#
# === RELEVANT DOCS (2) ===
# five [B: 156 - E: 160]
#   basic commodities [B: 161 - E: 178]
#
# 2 billion [B: 237 - E: 246]
#   $ [B: 236 - E: 237]
#
# === RETURNED DOCS (3) ===
# five [B: 156 - E: 160]
#   basic commodities [B: 161 - E: 178]
#
# 2 billion [B: 237 - E: 246]
#   Saudi Arabia [B: 261 - E: 273]
#
# 13th [B: 298 - E: 302]
#   August [B: 306 - E: 312]
#
# === SHARED DOCS (1) ===
# G: five [B: 156 - E: 160]
# P: five [B: 156 - E: 160]
#   === distance: 0 ===
#   G: basic commodities [B: 161 - E: 178]
#   P: basic commodities [B: 161 - E: 178]
#
# P: 0.3333333333333333, R: 0.5, F1: 0.4
# ##################################################
#
# Excerpt: a2_85701
#
# === RELEVANT DOCS (6) ===
# one [B: 2259 - E: 2262]
#   hospital [B: 2263 - E: 2271]
#
# two [B: 2280 - E: 2283]
#   doctors [B: 2284 - E: 2291]
#
# one and a half [B: 2347 - E: 2361]
#   years [B: 2362 - E: 2367]
#
# one [B: 2432 - E: 2435]
#   female doctor [B: 2436 - E: 2449]
#
# 15 [B: 2509 - E: 2511]
#   Venezuelan women [B: 2512 - E: 2528]
#
# two [B: 2800 - E: 2803]
#   confirmed cases of multidrug resistant tuberculosis [B: 2804 - E: 2855]
#
# === RETURNED DOCS (6) ===
# one [B: 2259 - E: 2262]
#   hospital [B: 2263 - E: 2271]
#
# two [B: 2280 - E: 2283]
#   doctors [B: 2284 - E: 2291]
#
# one [B: 2347 - E: 2350]
#   half years [B: 2357 - E: 2367]
#
# one [B: 2432 - E: 2435]
#   female doctor [B: 2436 - E: 2449]
#
# 15 [B: 2509 - E: 2511]
#   Venezuelan women [B: 2512 - E: 2528]
#
# two [B: 2800 - E: 2803]
#   cases [B: 2814 - E: 2819]
#
# === SHARED DOCS (6) ===
# G: 15 [B: 2509 - E: 2511]
# P: 15 [B: 2509 - E: 2511]
#   === distance: 0 ===
#   G: Venezuelan women [B: 2512 - E: 2528]
#   P: Venezuelan women [B: 2512 - E: 2528]
#
# G: one [B: 2259 - E: 2262]
# P: one [B: 2259 - E: 2262]
#   === distance: 0 ===
#   G: hospital [B: 2263 - E: 2271]
#   P: hospital [B: 2263 - E: 2271]
#
# G: two [B: 2800 - E: 2803]
# P: two [B: 2800 - E: 2803]
#   === distance: 46 ===
#   G: confirmed cases of multidrug resistant tuberculosis [B: 2804 - E: 2855]
#   P: cases [B: 2814 - E: 2819]
#
# G: one and a half [B: 2347 - E: 2361]
# P: one [B: 2347 - E: 2350]
#   === distance: 5 ===
#   G: years [B: 2362 - E: 2367]
#   P: half years [B: 2357 - E: 2367]
#
# G: two [B: 2280 - E: 2283]
# P: two [B: 2280 - E: 2283]
#   === distance: 0 ===
#   G: doctors [B: 2284 - E: 2291]
#   P: doctors [B: 2284 - E: 2291]
#
# G: one [B: 2432 - E: 2435]
# P: one [B: 2432 - E: 2435]
#   === distance: 0 ===
#   G: female doctor [B: 2436 - E: 2449]
#   P: female doctor [B: 2436 - E: 2449]
#
# P: 1.0, R: 1.0, F1: 1.0
# ##################################################
#
# Excerpt: a3_281963
#
# === RELEVANT DOCS (3) ===
# 4,638 [B: 58 - E: 63]
#   people [B: 64 - E: 70]
#
# 22% [B: 229 - E: 232]
#   people [B: 64 - E: 70]
#
# 7% [B: 331 - E: 333]
#   people [B: 64 - E: 70]
#
# === RETURNED DOCS (2) ===
# 4,638 [B: 58 - E: 63]
#   people [B: 64 - E: 70]
#
# one [B: 86 - E: 89]
#   interview [B: 90 - E: 99]
#
# === SHARED DOCS (1) ===
# G: 4,638 [B: 58 - E: 63]
# P: 4,638 [B: 58 - E: 63]
#   === distance: 0 ===
#   G: people [B: 64 - E: 70]
#   P: people [B: 64 - E: 70]
#
# P: 0.5, R: 0.3333333333333333, F1: 0.4
# ##################################################
#
# Excerpt: a1_159767
#
# === RELEVANT DOCS (3) ===
# seven [B: 155 - E: 160]
#   LGAs [B: 161 - E: 165]
#
# 49 [B: 170 - E: 172]
#   camps [B: 173 - E: 178]
#
# 83,000 [B: 184 - E: 190]
#   households [B: 191 - E: 201]
#
# === RETURNED DOCS (3) ===
# seven [B: 155 - E: 160]
#   LGAs [B: 161 - E: 165]
#
# 49 [B: 170 - E: 172]
#   camps [B: 173 - E: 178]
#
# 83,000 [B: 184 - E: 190]
#   households [B: 191 - E: 201]
#
# === SHARED DOCS (3) ===
# G: seven [B: 155 - E: 160]
# P: seven [B: 155 - E: 160]
#   === distance: 0 ===
#   G: LGAs [B: 161 - E: 165]
#   P: LGAs [B: 161 - E: 165]
#
# G: 49 [B: 170 - E: 172]
# P: 49 [B: 170 - E: 172]
#   === distance: 0 ===
#   G: camps [B: 173 - E: 178]
#   P: camps [B: 173 - E: 178]
#
# G: 83,000 [B: 184 - E: 190]
# P: 83,000 [B: 184 - E: 190]
#   === distance: 0 ===
#   G: households [B: 191 - E: 201]
#   P: households [B: 191 - E: 201]
#
# P: 1.0, R: 1.0, F1: 1.0
# ##################################################
#
# Excerpt: a1_272248
#
# === RELEVANT DOCS (7) ===
# 40 percent [B: 67 - E: 77]
#   Unemployment [B: 29 - E: 41]
#
# 33.5 percent [B: 204 - E: 216]
#   unemployment [B: 166 - E: 178]
#
# 23 percent [B: 231 - E: 241]
#   unemployment [B: 166 - E: 178]
#
# one third [B: 276 - E: 285]
#   jobs [B: 289 - E: 293]
#
# 4 [B: 585 - E: 586]
#   workers [B: 593 - E: 600]
#
# 4 in 10 [B: 585 - E: 592]
#   workers [B: 593 - E: 600]
#
# 10 [B: 590 - E: 592]
#   workers [B: 593 - E: 600]
#
# === RETURNED DOCS (2) ===
# one [B: 276 - E: 279]
#   third [B: 280 - E: 285]
#
# 10 [B: 590 - E: 592]
#   workers [B: 593 - E: 600]
#
# === SHARED DOCS (1) ===
# G: 4 in 10 [B: 585 - E: 592]
# P: 10 [B: 590 - E: 592]
#   === distance: 0 ===
#   G: workers [B: 593 - E: 600]
#   P: workers [B: 593 - E: 600]
#
# P: 0.5, R: 0.14285714285714285, F1: 0.22222222222222224
# ##################################################
#
# Excerpt: a1_313779
#
# === RELEVANT DOCS (2) ===
# 166 [B: 454 - E: 457]
#   households [B: 458 - E: 468]
#
# 1,860 [B: 472 - E: 477]
#   individuals [B: 478 - E: 489]
#
# === RETURNED DOCS (3) ===
# 3 [B: 38 - E: 39]
#   - [B: 39 - E: 40]
#
# 166 [B: 454 - E: 457]
#   households [B: 458 - E: 468]
#
# 1,860 [B: 472 - E: 477]
#   individuals [B: 478 - E: 489]
#
# === SHARED DOCS (2) ===
# G: 1,860 [B: 472 - E: 477]
# P: 1,860 [B: 472 - E: 477]
#   === distance: 0 ===
#   G: individuals [B: 478 - E: 489]
#   P: individuals [B: 478 - E: 489]
#
# G: 166 [B: 454 - E: 457]
# P: 166 [B: 454 - E: 457]
#   === distance: 0 ===
# ...
# P: 95 percent [B: 825 - E: 835]
#   === distance: 8 ===
#   G: population in need [B: 843 - E: 861]
#   P: population [B: 843 - E: 853]
#
# P: 0.45454545454545453, R: 0.625, F1: 0.5263157894736842
# ##################################################
#
# Excerpt: a1_345410
#
# === RELEVANT DOCS (3) ===
# 1,298 [B: 88 - E: 93]
#   individuals [B: 94 - E: 105]
#
# 3 per cent [B: 176 - E: 186]
#   individuals [B: 214 - E: 225]
#
# 1,336 [B: 208 - E: 213]
#   individuals [B: 214 - E: 225]
#
# === RETURNED DOCS (3) ===
# 1,298 [B: 88 - E: 93]
#   individuals [B: 94 - E: 105]
#
# 1,336 [B: 208 - E: 213]
#   individuals [B: 214 - E: 225]
#
# first [B: 716 - E: 721]
#   quarter [B: 722 - E: 729]
#
# === SHARED DOCS (2) ===
# G: 1,298 [B: 88 - E: 93]
# P: 1,298 [B: 88 - E: 93]
#   === distance: 0 ===
#   G: individuals [B: 94 - E: 105]
#   P: individuals [B: 94 - E: 105]
#
# G: 1,336 [B: 208 - E: 213]
# P: 1,336 [B: 208 - E: 213]
#   === distance: 0 ===
#   G: individuals [B: 214 - E: 225]
#   P: individuals [B: 214 - E: 225]
#
# P: 0.6666666666666666, R: 0.6666666666666666, F1: 0.6666666666666666
# ##################################################
#
# Excerpt: a1_255434
#
# === RELEVANT DOCS (9) ===
# 940,000 [B: 53 - E: 60]
#   people [B: 61 - E: 67]
#
# 194,000 [B: 78 - E: 85]
#   women [B: 90 - E: 95]
#
# 566,000 [B: 100 - E: 107]
#   children [B: 112 - E: 120]
#
# 2.7 million [B: 181 - E: 192]
#   people [B: 193 - E: 199]
#
# four million [B: 235 - E: 247]
#   people [B: 248 - E: 254]
#
# 2.8 million [B: 280 - E: 291]
#   people [B: 248 - E: 254]
#
# one [B: 643 - E: 646]
#   week [B: 647 - E: 651]
#
# five [B: 685 - E: 689]
#   children [B: 690 - E: 698]
#
# two [B: 816 - E: 819]
#   aid workers [B: 820 - E: 831]
#
# === RETURNED DOCS (12) ===
# 2020 [B: 12 - E: 16]
#   NWS [B: 17 - E: 20]
#
# 940,000 [B: 53 - E: 60]
#   people [B: 61 - E: 67]
#
# 194,000 [B: 78 - E: 85]
# P: 0.375, R: 0.3, F1: 0.33333333333333326
# ##################################################
#
# Excerpt: a3_179161
#
# === RELEVANT DOCS (15) ===
# 19 percent [B: 104 - E: 114]
#   prevalence of  chronic malnutrition among children aged 6-59 months [B: 21 - E: 88]
#
# 19 percent to 33 percent [B: 104 - E: 128]
#   prevalence of  chronic malnutrition among children aged 6-59 months [B: 21 - E: 88]
#
# 33 percent [B: 118 - E: 128]
#   prevalence of  chronic malnutrition among children aged 6-59 months [B: 21 - E: 88]
#
# 35percent [B: 130 - E: 139]
#   prevalence of  chronic malnutrition among children aged 6-59 months [B: 21 - E: 88]
#
# 31percent [B: 150 - E: 159]
#   prevalence of  chronic malnutrition among children aged 6-59 months [B: 21 - E: 88]
#
# 1 percent [B: 265 - E: 274]
#   prevalence of acute malnutrition [B: 217 - E: 249]
#
# 1 percent to 2 percent [B: 265 - E: 287]
#   prevalence of acute malnutrition [B: 217 - E: 249]
#
# 2 percent [B: 278 - E: 287]
#   prevalence of acute malnutrition [B: 217 - E: 249]
#
# 11 percent [B: 417 - E: 427]
#   prevalence of acute malnutrition across northwest Syria [B: 355 - E: 410]
#
# 4 percent [B: 622 - E: 631]
#   prevalence  of  acute  malnutrition [B: 511 - E: 546]
#
# 4 percent vs. 1 percent [B: 622 - E: 645]
#   prevalence  of  acute  malnutrition [B: 511 - E: 546]
#
# 1 percent [B: 636 - E: 645]
#   prevalence  of  acute  malnutrition [B: 511 - E: 546]
#
# 20 percent [B: 656 - E: 666]
#   prevalence  of  acute  malnutrition [B: 511 - E: 546]
#
# 20 percent vs. 2 percent [B: 656 - E: 680]
#   prevalence  of  acute  malnutrition [B: 511 - E: 546]
#
# 2 percent [B: 671 - E: 680]
#   prevalence  of  acute  malnutrition [B: 511 - E: 546]
#
# === RETURNED DOCS (9) ===
# 6 [B: 77 - E: 78]
#   - [B: 78 - E: 79]
#
# 33 percent [B: 118 - E: 128]
#   35percent [B: 130 - E: 139]
#
# 35percent [B: 130 - E: 139]
#   boys [B: 144 - E: 148]
#
# 6 [B: 609 - E: 610]
#   - [B: 610 - E: 611]
#
# 4 percent [B: 622 - E: 631]
#   PLW [B: 651 - E: 654]
#
# 20 percent [B: 656 - E: 666]
#   percent)and [B: 673 - E: 684]
#
# 2 [B: 671 - E: 672]
#   percent)and [B: 673 - E: 684]
#
# 6 [B: 753 - E: 754]
#   - [B: 754 - E: 755]
#
# second [B: 912 - E: 918]
#   half [B: 920 - E: 924]
#
# === SHARED DOCS (0) ===
# P: 0.0, R: 0.0, F1: 0.0
# ##################################################
#
# Excerpt: a2a3_361401
#
# === RELEVANT DOCS (1) ===
# 5 [B: 561 - E: 562]
#   children [B: 546 - E: 554]
#
# === RETURNED DOCS (0) ===
# === SHARED DOCS (0) ===
# P: 0.0, R: 0.0, F1: 0.0
# ##################################################
#
# Excerpt: a2_78512
#
# === RELEVANT DOCS (10) ===
# 28 [B: 5 - E: 7]
#   people [B: 8 - E: 14]
#
# 14 [B: 60 - E: 62]
#   casualties [B: 63 - E: 73]
#   === distance: 0 ===
#   G: casualties [B: 63 - E: 73]
#   P: casualties [B: 63 - E: 73]
#
# P: 0.8181818181818182, R: 0.9, F1: 0.8571428571428572
# ##################################################
#
# Excerpt: a2_187638
#
# === RELEVANT DOCS (4) ===
# 70 [B: 9 - E: 11]
#   health workers [B: 12 - E: 26]
#
# two [B: 143 - E: 146]
#   Health Care Facility/Maternal Child Health Centres [B: 147 - E: 197]
#
# 10 [B: 476 - E: 478]
#   persons [B: 479 - E: 486]
#
# Two [B: 704 - E: 707]
#   overcrowded IDP sites [B: 708 - E: 729]
#
# === RETURNED DOCS (4) ===
# 70 [B: 9 - E: 11]
#   health workers [B: 12 - E: 26]
#
# two [B: 143 - E: 146]
#   Health Care Facility/Maternal Child Health Centres [B: 147 - E: 197]
#
# 10 [B: 476 - E: 478]
#   persons [B: 479 - E: 486]
#
# Two [B: 704 - E: 707]
#   overcrowded IDP sites [B: 708 - E: 729]
#
# === SHARED DOCS (4) ===
# G: 10 [B: 476 - E: 478]
# P: 10 [B: 476 - E: 478]
#   === distance: 0 ===
#   G: persons [B: 479 - E: 486]
#   P: persons [B: 479 - E: 486]
#
# G: 70 [B: 9 - E: 11]
# P: 70 [B: 9 - E: 11]
#   === distance: 0 ===
#   G: health workers [B: 12 - E: 26]
#   P: health workers [B: 12 - E: 26]
#
# G: Two [B: 704 - E: 707]
# P: Two [B: 704 - E: 707]
#   === distance: 0 ===
#   G: overcrowded IDP sites [B: 708 - E: 729]
#   P: overcrowded IDP sites [B: 708 - E: 729]
#
# G: two [B: 143 - E: 146]
# P: two [B: 143 - E: 146]
#   === distance: 0 ===
#   G: Health Care Facility/Maternal Child Health Centres [B: 147 - E: 197]
#   P: Health Care Facility/Maternal Child Health Centres [B: 147 - E: 197]
#
# P: 1.0, R: 1.0, F1: 1.0
# ##################################################
#
# Excerpt: a2_259957
#
# === RELEVANT DOCS (4) ===
# 25 [B: 414 - E: 416]
#   counties [B: 417 - E: 425]
#
# 193 [B: 613 - E: 616]
#   health facilities [B: 617 - E: 634]
#
# 15,000 [B: 911 - E: 917]
#   target population [B: 890 - E: 907]
#
# 15,000 [B: 911 - E: 917]
#   people [B: 918 - E: 924]
#
# === RETURNED DOCS (5) ===
# third [B: 289 - E: 294]
#   quarter [B: 295 - E: 302]
#
# 25 [B: 414 - E: 416]
#   counties [B: 417 - E: 425]
#
# fourth [B: 578 - E: 584]
#   quarter [B: 585 - E: 592]
#
# 193 [B: 613 - E: 616]
#   all [B: 605 - E: 608]
#
# 15,000 [B: 911 - E: 917]
#   people [B: 918 - E: 924]
#
# === SHARED DOCS (2) ===
# G: 15,000 [B: 911 - E: 917]
# P: 15,000 [B: 911 - E: 917]
#   === distance: 0 ===
#   G: people [B: 918 - E: 924]
#   P: people [B: 918 - E: 924]
#
# G: 25 [B: 414 - E: 416]
# P: 25 [B: 414 - E: 416]
#   === distance: 0 ===
#   G: counties [B: 417 - E: 425]
#   P: counties [B: 417 - E: 425]
#
