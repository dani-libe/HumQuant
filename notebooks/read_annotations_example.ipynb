# %%
import os
import spacy
import pickle
import random
from cassis import load_typesystem, load_cas_from_xmi
import pandas as pd
import numpy as np

# %%
def get_paths(test_set_metadata_path, rounds_path="../data/annotations_and_sources"):
  paths_data = {}

  with open(test_set_metadata_path, "rb") as f:
    test_set_metadata = pickle.load(f)

  for fname, annotator in test_set_metadata.items():
    paths_data[fname] = {}
    paths_data[fname]["annotations"] = f"{rounds_path}/annotation/{fname}.txt/{annotator}/{annotator}.xmi"
    paths_data[fname]["typesystem"] = f"{rounds_path}/annotation/{fname}.txt/{annotator}/TypeSystem.xml"
    paths_data[fname]["source"] = f"{rounds_path}/source/{fname}.txt"
    
  return paths_data

# %%
def get_cas(paths):
  with open(paths["typesystem"], "rb") as f:
    typesystem = load_typesystem(f)
    
  with open(paths["annotations"], "rb") as f:
    cas = load_cas_from_xmi(f, typesystem=typesystem)

  return cas

# %%
def get_annotated_units(paths_data):
  ground_truth = {}
  get_main_info = lambda ground_elem: (ground_elem.get_covered_text(), pd.Interval(ground_elem.begin, ground_elem.end, closed="left"))

  for fname, paths in paths_data.items():
    ground_truth[fname] = {}

    cas = get_cas(paths)

    ground_numbers = [ann for ann in cas.select("custom.Span") if ann.label == "Number"]
    ground_units = [(ann.Governor, ann.Dependent) for ann in cas.select("custom.Relation") if ann.Governor.label == "Number" and ann.Dependent.label == "Unit"]

    for ground_number in ground_numbers:
      ground_n = get_main_info(ground_number)
      ground_truth[fname][ground_n] = []

    for ground_number, ground_unit in ground_units:
      ground_n = get_main_info(ground_number)
      ground_u = get_main_info(ground_unit)
      ground_truth[fname][ground_n].append(ground_u)

  return ground_truth

# %%
TEST_SET_METADATA_PATH = "../data/test_set_metadata.pkl"
paths = get_paths(TEST_SET_METADATA_PATH)

# %%
paths
# Out:
# {'a2_6051': {'annotations': '../data/annotations_and_sources/annotation/a2_6051.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_6051.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_6051.txt'},
#  'a2_186485': {'annotations': '../data/annotations_and_sources/annotation/a2_186485.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_186485.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_186485.txt'},
#  'a2_26483': {'annotations': '../data/annotations_and_sources/annotation/a2_26483.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_26483.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_26483.txt'},
#  'a3_223620': {'annotations': '../data/annotations_and_sources/annotation/a3_223620.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_223620.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_223620.txt'},
#  'a3_186686': {'annotations': '../data/annotations_and_sources/annotation/a3_186686.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_186686.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_186686.txt'},
#  'a1_22580': {'annotations': '../data/annotations_and_sources/annotation/a1_22580.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_22580.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_22580.txt'},
#  'a2_113618': {'annotations': '../data/annotations_and_sources/annotation/a2_113618.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_113618.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_113618.txt'},
#  'a2_317769': {'annotations': '../data/annotations_and_sources/annotation/a2_317769.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_317769.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_317769.txt'},
#  'a3_57314': {'annotations': '../data/annotations_and_sources/annotation/a3_57314.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_57314.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_57314.txt'},
#  'a2a3_15631': {'annotations': '../data/annotations_and_sources/annotation/a2a3_15631.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2a3_15631.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2a3_15631.txt'},
#  'a1a2_352039': {'annotations': '../data/annotations_and_sources/annotation/a1a2_352039.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a2_352039.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a2_352039.txt'},
#  'a1_363350': {'annotations': '../data/annotations_and_sources/annotation/a1_363350.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_363350.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_363350.txt'},
#  'a1a3_11483': {'annotations': '../data/annotations_and_sources/annotation/a1a3_11483.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a3_11483.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a3_11483.txt'},
#  'a1a2_57316': {'annotations': '../data/annotations_and_sources/annotation/a1a2_57316.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a2_57316.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a2_57316.txt'},
#  'a3_104965': {'annotations': '../data/annotations_and_sources/annotation/a3_104965.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_104965.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_104965.txt'},
#  'a3_385303': {'annotations': '../data/annotations_and_sources/annotation/a3_385303.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_385303.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_385303.txt'},
#  'a2_75113': {'annotations': '../data/annotations_and_sources/annotation/a2_75113.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_75113.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_75113.txt'},
#  'a1a3_25314': {'annotations': '../data/annotations_and_sources/annotation/a1a3_25314.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a3_25314.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a3_25314.txt'},
#  'a2_62075': {'annotations': '../data/annotations_and_sources/annotation/a2_62075.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_62075.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_62075.txt'},
#  'a2_357797': {'annotations': '../data/annotations_and_sources/annotation/a2_357797.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_357797.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_357797.txt'},
#  'a2_13554': {'annotations': '../data/annotations_and_sources/annotation/a2_13554.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_13554.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_13554.txt'},
#  'a2a3_275581': {'annotations': '../data/annotations_and_sources/annotation/a2a3_275581.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2a3_275581.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2a3_275581.txt'},
#  'a1_241237': {'annotations': '../data/annotations_and_sources/annotation/a1_241237.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_241237.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_241237.txt'},
#  'a3_287956': {'annotations': '../data/annotations_and_sources/annotation/a3_287956.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_287956.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_287956.txt'},
#  'a3_338882': {'annotations': '../data/annotations_and_sources/annotation/a3_338882.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_338882.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_338882.txt'},
#  'a1_241888': {'annotations': '../data/annotations_and_sources/annotation/a1_241888.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_241888.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_241888.txt'},
#  'a2a3_310409': {'annotations': '../data/annotations_and_sources/annotation/a2a3_310409.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2a3_310409.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2a3_310409.txt'},
#  'a1_316396': {'annotations': '../data/annotations_and_sources/annotation/a1_316396.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_316396.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_316396.txt'},
#  'a2_11626': {'annotations': '../data/annotations_and_sources/annotation/a2_11626.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_11626.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_11626.txt'},
#  'a2_85701': {'annotations': '../data/annotations_and_sources/annotation/a2_85701.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_85701.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_85701.txt'},
#  'a3_281963': {'annotations': '../data/annotations_and_sources/annotation/a3_281963.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_281963.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_281963.txt'},
#  'a1_159767': {'annotations': '../data/annotations_and_sources/annotation/a1_159767.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_159767.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_159767.txt'},
#  'a1_272248': {'annotations': '../data/annotations_and_sources/annotation/a1_272248.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_272248.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_272248.txt'},
#  'a1_313779': {'annotations': '../data/annotations_and_sources/annotation/a1_313779.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_313779.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_313779.txt'},
#  'a3_102620': {'annotations': '../data/annotations_and_sources/annotation/a3_102620.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_102620.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_102620.txt'},
#  'a2_193683': {'annotations': '../data/annotations_and_sources/annotation/a2_193683.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_193683.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_193683.txt'},
#  'a2_310991': {'annotations': '../data/annotations_and_sources/annotation/a2_310991.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_310991.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_310991.txt'},
#  'a2_179271': {'annotations': '../data/annotations_and_sources/annotation/a2_179271.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_179271.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_179271.txt'},
#  'a1a2_160839': {'annotations': '../data/annotations_and_sources/annotation/a1a2_160839.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a2_160839.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a2_160839.txt'},
#  'a2_57313': {'annotations': '../data/annotations_and_sources/annotation/a2_57313.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_57313.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_57313.txt'},
#  'a2_14175': {'annotations': '../data/annotations_and_sources/annotation/a2_14175.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_14175.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_14175.txt'},
#  'a2_134019': {'annotations': '../data/annotations_and_sources/annotation/a2_134019.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_134019.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_134019.txt'},
#  'a1_187709': {'annotations': '../data/annotations_and_sources/annotation/a1_187709.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_187709.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_187709.txt'},
#  'a3_327403': {'annotations': '../data/annotations_and_sources/annotation/a3_327403.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_327403.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_327403.txt'},
#  'a3_35922': {'annotations': '../data/annotations_and_sources/annotation/a3_35922.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_35922.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_35922.txt'},
#  'a2_336798': {'annotations': '../data/annotations_and_sources/annotation/a2_336798.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_336798.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_336798.txt'},
#  'a1_166931': {'annotations': '../data/annotations_and_sources/annotation/a1_166931.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_166931.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_166931.txt'},
#  'a3_185667': {'annotations': '../data/annotations_and_sources/annotation/a3_185667.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_185667.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_185667.txt'},
#  'a2_224705': {'annotations': '../data/annotations_and_sources/annotation/a2_224705.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_224705.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_224705.txt'},
#  'a2_291034': {'annotations': '../data/annotations_and_sources/annotation/a2_291034.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_291034.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_291034.txt'},
#  'a2_225143': {'annotations': '../data/annotations_and_sources/annotation/a2_225143.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_225143.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_225143.txt'},
#  'a1_1871': {'annotations': '../data/annotations_and_sources/annotation/a1_1871.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_1871.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_1871.txt'},
#  'a1a3_241887': {'annotations': '../data/annotations_and_sources/annotation/a1a3_241887.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a3_241887.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a3_241887.txt'},
#  'a1_281962': {'annotations': '../data/annotations_and_sources/annotation/a1_281962.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_281962.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_281962.txt'},
#  'a1_167386': {'annotations': '../data/annotations_and_sources/annotation/a1_167386.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_167386.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_167386.txt'},
#  'a1a3_264773': {'annotations': '../data/annotations_and_sources/annotation/a1a3_264773.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a3_264773.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a3_264773.txt'},
#  'a2_17511': {'annotations': '../data/annotations_and_sources/annotation/a2_17511.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_17511.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_17511.txt'},
#  'a2_80876': {'annotations': '../data/annotations_and_sources/annotation/a2_80876.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_80876.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_80876.txt'},
#  'a1a3_37730': {'annotations': '../data/annotations_and_sources/annotation/a1a3_37730.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a3_37730.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a3_37730.txt'},
#  'a2_190106': {'annotations': '../data/annotations_and_sources/annotation/a2_190106.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_190106.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_190106.txt'},
#  'a3_83995': {'annotations': '../data/annotations_and_sources/annotation/a3_83995.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_83995.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_83995.txt'},
#  'a3_271261': {'annotations': '../data/annotations_and_sources/annotation/a3_271261.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_271261.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_271261.txt'},
#  'a1_83005': {'annotations': '../data/annotations_and_sources/annotation/a1_83005.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_83005.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_83005.txt'},
#  'a1_100228': {'annotations': '../data/annotations_and_sources/annotation/a1_100228.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_100228.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_100228.txt'},
#  'a3_241903': {'annotations': '../data/annotations_and_sources/annotation/a3_241903.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_241903.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_241903.txt'},
#  'a2_313446': {'annotations': '../data/annotations_and_sources/annotation/a2_313446.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_313446.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_313446.txt'},
#  'a3_286910': {'annotations': '../data/annotations_and_sources/annotation/a3_286910.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_286910.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_286910.txt'},
#  'a3_76946': {'annotations': '../data/annotations_and_sources/annotation/a3_76946.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_76946.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_76946.txt'},
#  'a2a3_360171': {'annotations': '../data/annotations_and_sources/annotation/a2a3_360171.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2a3_360171.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2a3_360171.txt'},
#  'a1a2_85694': {'annotations': '../data/annotations_and_sources/annotation/a1a2_85694.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a2_85694.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a2_85694.txt'},
#  'a2_71399': {'annotations': '../data/annotations_and_sources/annotation/a2_71399.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_71399.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_71399.txt'},
#  'a2_354625': {'annotations': '../data/annotations_and_sources/annotation/a2_354625.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_354625.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_354625.txt'},
#  'a2_320172': {'annotations': '../data/annotations_and_sources/annotation/a2_320172.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_320172.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_320172.txt'},
#  'a2_1956': {'annotations': '../data/annotations_and_sources/annotation/a2_1956.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_1956.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_1956.txt'},
#  'a2a3_221882': {'annotations': '../data/annotations_and_sources/annotation/a2a3_221882.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2a3_221882.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2a3_221882.txt'},
#  'a2_331180': {'annotations': '../data/annotations_and_sources/annotation/a2_331180.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_331180.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_331180.txt'},
#  'a1_235312': {'annotations': '../data/annotations_and_sources/annotation/a1_235312.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_235312.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_235312.txt'},
#  'a2_360241': {'annotations': '../data/annotations_and_sources/annotation/a2_360241.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_360241.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_360241.txt'},
#  'a3_341206': {'annotations': '../data/annotations_and_sources/annotation/a3_341206.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_341206.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_341206.txt'},
#  'a2_61142': {'annotations': '../data/annotations_and_sources/annotation/a2_61142.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_61142.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_61142.txt'},
#  'a2_1883': {'annotations': '../data/annotations_and_sources/annotation/a2_1883.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_1883.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_1883.txt'},
#  'a3_163647': {'annotations': '../data/annotations_and_sources/annotation/a3_163647.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_163647.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_163647.txt'},
#  'a3_300160': {'annotations': '../data/annotations_and_sources/annotation/a3_300160.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_300160.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_300160.txt'},
#  'a2_243308': {'annotations': '../data/annotations_and_sources/annotation/a2_243308.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_243308.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_243308.txt'},
#  'a3_63865': {'annotations': '../data/annotations_and_sources/annotation/a3_63865.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_63865.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_63865.txt'},
#  'a1_89567': {'annotations': '../data/annotations_and_sources/annotation/a1_89567.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_89567.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_89567.txt'},
#  'a1a3_238348': {'annotations': '../data/annotations_and_sources/annotation/a1a3_238348.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a3_238348.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a3_238348.txt'},
#  'a2a3_489257': {'annotations': '../data/annotations_and_sources/annotation/a2a3_489257.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2a3_489257.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2a3_489257.txt'},
#  'a1_402271': {'annotations': '../data/annotations_and_sources/annotation/a1_402271.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_402271.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_402271.txt'},
#  'a1_37265': {'annotations': '../data/annotations_and_sources/annotation/a1_37265.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_37265.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_37265.txt'},
#  'a3_15124': {'annotations': '../data/annotations_and_sources/annotation/a3_15124.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_15124.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_15124.txt'},
#  'a2_351206': {'annotations': '../data/annotations_and_sources/annotation/a2_351206.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_351206.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_351206.txt'},
#  'a2_218973': {'annotations': '../data/annotations_and_sources/annotation/a2_218973.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_218973.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_218973.txt'},
#  'a2a3_63403': {'annotations': '../data/annotations_and_sources/annotation/a2a3_63403.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2a3_63403.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2a3_63403.txt'},
#  'a1_320956': {'annotations': '../data/annotations_and_sources/annotation/a1_320956.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_320956.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_320956.txt'},
#  'a1_260514': {'annotations': '../data/annotations_and_sources/annotation/a1_260514.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_260514.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_260514.txt'},
#  'a3_286516': {'annotations': '../data/annotations_and_sources/annotation/a3_286516.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_286516.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_286516.txt'},
#  'a2_320960': {'annotations': '../data/annotations_and_sources/annotation/a2_320960.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_320960.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_320960.txt'},
#  'a3_134023': {'annotations': '../data/annotations_and_sources/annotation/a3_134023.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_134023.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_134023.txt'},
#  'a1a3_22937': {'annotations': '../data/annotations_and_sources/annotation/a1a3_22937.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a3_22937.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a3_22937.txt'},
#  'a3_297416': {'annotations': '../data/annotations_and_sources/annotation/a3_297416.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_297416.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_297416.txt'},
#  'a1_314901': {'annotations': '../data/annotations_and_sources/annotation/a1_314901.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_314901.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_314901.txt'},
#  'a1_275538': {'annotations': '../data/annotations_and_sources/annotation/a1_275538.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_275538.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_275538.txt'},
#  'a3_7633': {'annotations': '../data/annotations_and_sources/annotation/a3_7633.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_7633.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_7633.txt'},
#  'a3_278075': {'annotations': '../data/annotations_and_sources/annotation/a3_278075.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_278075.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_278075.txt'},
#  'a2_312553': {'annotations': '../data/annotations_and_sources/annotation/a2_312553.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_312553.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_312553.txt'},
#  'a2_173196': {'annotations': '../data/annotations_and_sources/annotation/a2_173196.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_173196.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_173196.txt'},
#  'a1_301848': {'annotations': '../data/annotations_and_sources/annotation/a1_301848.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_301848.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_301848.txt'},
#  'a3_264058': {'annotations': '../data/annotations_and_sources/annotation/a3_264058.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_264058.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_264058.txt'},
#  'a1_54415': {'annotations': '../data/annotations_and_sources/annotation/a1_54415.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_54415.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_54415.txt'},
#  'a3_6276': {'annotations': '../data/annotations_and_sources/annotation/a3_6276.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_6276.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_6276.txt'},
#  'a3_79842': {'annotations': '../data/annotations_and_sources/annotation/a3_79842.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_79842.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_79842.txt'},
#  'a3_100572': {'annotations': '../data/annotations_and_sources/annotation/a3_100572.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_100572.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_100572.txt'},
#  'a3_316495': {'annotations': '../data/annotations_and_sources/annotation/a3_316495.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_316495.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_316495.txt'},
#  'a3_393172': {'annotations': '../data/annotations_and_sources/annotation/a3_393172.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_393172.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_393172.txt'},
#  'a2a3_295634': {'annotations': '../data/annotations_and_sources/annotation/a2a3_295634.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2a3_295634.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2a3_295634.txt'},
#  'a1a2_410083': {'annotations': '../data/annotations_and_sources/annotation/a1a2_410083.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a2_410083.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a2_410083.txt'},
#  'a3_57312': {'annotations': '../data/annotations_and_sources/annotation/a3_57312.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_57312.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_57312.txt'},
#  'a1_313209': {'annotations': '../data/annotations_and_sources/annotation/a1_313209.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_313209.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_313209.txt'},
#  'a3_293833': {'annotations': '../data/annotations_and_sources/annotation/a3_293833.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_293833.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_293833.txt'},
#  'a2_267842': {'annotations': '../data/annotations_and_sources/annotation/a2_267842.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_267842.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_267842.txt'},
#  'a3_45163': {'annotations': '../data/annotations_and_sources/annotation/a3_45163.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_45163.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_45163.txt'},
#  'a2_337839': {'annotations': '../data/annotations_and_sources/annotation/a2_337839.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_337839.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_337839.txt'},
#  'a2a3_393214': {'annotations': '../data/annotations_and_sources/annotation/a2a3_393214.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2a3_393214.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2a3_393214.txt'},
#  'a3_286524': {'annotations': '../data/annotations_and_sources/annotation/a3_286524.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_286524.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_286524.txt'},
#  'a3_167322': {'annotations': '../data/annotations_and_sources/annotation/a3_167322.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_167322.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_167322.txt'},
#  'a1_309286': {'annotations': '../data/annotations_and_sources/annotation/a1_309286.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_309286.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_309286.txt'},
#  'a3_229819': {'annotations': '../data/annotations_and_sources/annotation/a3_229819.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_229819.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_229819.txt'},
#  'a2a3_198853': {'annotations': '../data/annotations_and_sources/annotation/a2a3_198853.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2a3_198853.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2a3_198853.txt'},
#  'a1_393170': {'annotations': '../data/annotations_and_sources/annotation/a1_393170.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_393170.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_393170.txt'},
#  'a2_281837': {'annotations': '../data/annotations_and_sources/annotation/a2_281837.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_281837.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_281837.txt'},
#  'a1_1821': {'annotations': '../data/annotations_and_sources/annotation/a1_1821.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_1821.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_1821.txt'},
#  'a3_174630': {'annotations': '../data/annotations_and_sources/annotation/a3_174630.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_174630.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_174630.txt'},
#  'a1a2_192685': {'annotations': '../data/annotations_and_sources/annotation/a1a2_192685.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a2_192685.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a2_192685.txt'},
#  'a1a2_48603': {'annotations': '../data/annotations_and_sources/annotation/a1a2_48603.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a2_48603.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a2_48603.txt'},
#  'a1a3_295505': {'annotations': '../data/annotations_and_sources/annotation/a1a3_295505.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1a3_295505.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1a3_295505.txt'},
#  'a3_363341': {'annotations': '../data/annotations_and_sources/annotation/a3_363341.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_363341.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_363341.txt'},
#  'a2_5757': {'annotations': '../data/annotations_and_sources/annotation/a2_5757.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_5757.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_5757.txt'},
#  'a1_62106': {'annotations': '../data/annotations_and_sources/annotation/a1_62106.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_62106.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_62106.txt'},
#  'a1_173902': {'annotations': '../data/annotations_and_sources/annotation/a1_173902.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_173902.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_173902.txt'},
#  'a2_306095': {'annotations': '../data/annotations_and_sources/annotation/a2_306095.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_306095.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_306095.txt'},
#  'a3_24902': {'annotations': '../data/annotations_and_sources/annotation/a3_24902.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_24902.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_24902.txt'},
#  'a2_215316': {'annotations': '../data/annotations_and_sources/annotation/a2_215316.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_215316.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_215316.txt'},
#  'a2_33790': {'annotations': '../data/annotations_and_sources/annotation/a2_33790.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_33790.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_33790.txt'},
#  'a3_215291': {'annotations': '../data/annotations_and_sources/annotation/a3_215291.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_215291.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_215291.txt'},
#  'a3_248406': {'annotations': '../data/annotations_and_sources/annotation/a3_248406.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_248406.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_248406.txt'},
#  'a1_345410': {'annotations': '../data/annotations_and_sources/annotation/a1_345410.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_345410.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_345410.txt'},
#  'a1_255434': {'annotations': '../data/annotations_and_sources/annotation/a1_255434.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_255434.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_255434.txt'},
#  'a1_17111': {'annotations': '../data/annotations_and_sources/annotation/a1_17111.txt/annotator1/annotator1.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a1_17111.txt/annotator1/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a1_17111.txt'},
#  'a2_309932': {'annotations': '../data/annotations_and_sources/annotation/a2_309932.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_309932.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_309932.txt'},
#  'a3_179161': {'annotations': '../data/annotations_and_sources/annotation/a3_179161.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a3_179161.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a3_179161.txt'},
#  'a2a3_361401': {'annotations': '../data/annotations_and_sources/annotation/a2a3_361401.txt/annotator3/annotator3.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2a3_361401.txt/annotator3/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2a3_361401.txt'},
#  'a2_78512': {'annotations': '../data/annotations_and_sources/annotation/a2_78512.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_78512.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_78512.txt'},
#  'a2_187638': {'annotations': '../data/annotations_and_sources/annotation/a2_187638.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_187638.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_187638.txt'},
#  'a2_259957': {'annotations': '../data/annotations_and_sources/annotation/a2_259957.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_259957.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_259957.txt'},
#  'a2_186732': {'annotations': '../data/annotations_and_sources/annotation/a2_186732.txt/annotator2/annotator2.xmi',
#   'typesystem': '../data/annotations_and_sources/annotation/a2_186732.txt/annotator2/TypeSystem.xml',
#   'source': '../data/annotations_and_sources/source/a2_186732.txt'}}

# %%
# Number of excerpts in the test set
len(paths.keys())
# Out:
# 156

# %%
annotated_units = get_annotated_units(paths)

# %%
annotated_units
# Out:
# {'a2_6051': {('1.1 million',
#    Interval(270, 281, closed='left')): [('people',
#     Interval(282, 288, closed='left'))],
#   ('378,000',
#    Interval(299, 306, closed='left')): [('children',
#     Interval(311, 319, closed='left'))],
#   ('307,000',
#    Interval(324, 331, closed='left')): [('women',
#     Interval(336, 341, closed='left'))]},
#  'a2_186485': {('84%',
#    Interval(104, 107, closed='left')): [('women',
#     Interval(111, 116, closed='left'))],
#   ('5%', Interval(170, 172, closed='left')): [],
#   ('35%',
#    Interval(230, 233, closed='left')): [('women',
#     Interval(237, 242, closed='left'))],
#   ('50%',
#    Interval(282, 285, closed='left')): [('men',
#     Interval(289, 292, closed='left'))]},
#  'a2_26483': {('60%', Interval(88, 91, closed='left')): [],
#   ('70%', Interval(121, 124, closed='left')): []},
#  'a3_223620': {('10 percent',
#    Interval(79, 89, closed='left')): [('livestock production',
#     Interval(30, 50, closed='left'))],
#   ('60 percent',
#    Interval(121, 131, closed='left')): [('livestock production',
#     Interval(30, 50, closed='left'))]},
#  'a3_186686': {('42 per cent',
#    Interval(43, 54, closed='left')): [('households',
#     Interval(58, 68, closed='left'))]},
#  'a1_22580': {('16',
#    Interval(43, 45, closed='left')): [('states in Nigeria',
#     Interval(46, 63, closed='left'))],
#   ('213',
#    Interval(171, 174, closed='left')): [('confirmed cases',
#     Interval(175, 190, closed='left'))],
#   ('42',
#    Interval(210, 212, closed='left')): [('deaths',
#     Interval(213, 219, closed='left'))],
#   ('third',
#    Interval(261, 266, closed='left')): [('total cases',
#     Interval(274, 285, closed='left'))],
#   ('Four',
#    Interval(368, 372, closed='left')): [('health workers',
#     Interval(373, 387, closed='left'))],
#   ('12',
#    Interval(450, 452, closed='left')): [('cases',
#     Interval(453, 458, closed='left'))],
#   ('two',
#    Interval(533, 536, closed='left')): [('deaths',
#     Interval(537, 543, closed='left'))]},
#  'a2_113618': {('600 million',
#    Interval(61, 72, closed='left')): [('PEN',
#     Interval(57, 60, closed='left'))],
#   ('175 million',
#    Interval(92, 103, closed='left')): [('USD',
#     Interval(88, 91, closed='left'))],
#   ('760',
#    Interval(730, 733, closed='left')): [('PEN',
#     Interval(726, 729, closed='left'))],
#   ('220',
#    Interval(745, 748, closed='left')): [('USD',
#     Interval(741, 744, closed='left'))],
#   ('1 million',
#    Interval(753, 762, closed='left')): [('households',
#     Interval(780, 790, closed='left'))]},
#  'a2_317769': {('nine',
#    Interval(44, 48, closed='left')): [('humanitarians',
#     Interval(49, 62, closed='left'))],
#   ('five',
#    Interval(66, 70, closed='left')): [('different incidents',
#     Interval(71, 90, closed='left'))],
#   ('One',
#    Interval(92, 95, closed='left')): [('NGO security guard',
#     Interval(96, 114, closed='left'))],
#   ('four',
#    Interval(199, 203, closed='left')): [('instances',
#     Interval(204, 213, closed='left'))],
#   ('two',
#    Interval(374, 377, closed='left')): [('DPS vehicles',
#     Interval(378, 390, closed='left'))],
#   ('five',
#    Interval(616, 620, closed='left')): [('escort personnel',
#     Interval(621, 637, closed='left'))]},
#  'a3_57314': {('four',
#    Interval(138, 142, closed='left')): [('communities',
#     Interval(143, 154, closed='left'))],
#   ('two',
#    Interval(186, 189, closed='left')): [('communities',
#     Interval(190, 201, closed='left'))],
#   ('Nine',
#    Interval(222, 226, closed='left')): [('family VIP latrines',
#     Interval(227, 246, closed='left'))],
#   ('157',
#    Interval(260, 263, closed='left')): [('migrants',
#     Interval(264, 272, closed='left'))],
#   ('65',
#    Interval(277, 279, closed='left')): [('host community persons',
#     Interval(280, 302, closed='left'))],
#   ('50:50',
#    Interval(304, 309, closed='left')): [('male to female',
#     Interval(310, 324, closed='left'))],
#   ('30%',
#    Interval(326, 329, closed='left')): [('children',
#     Interval(330, 338, closed='left'))],
#   ('6',
#    Interval(345, 346, closed='left')): [('Rain Water Harvesting (RWH) units',
#     Interval(347, 380, closed='left'))],
#   ('43',
#    Interval(474, 476, closed='left')): [('VIP latrines',
#     Interval(477, 489, closed='left'))]},
#  'a2a3_15631': {('14,795',
#    Interval(81, 87, closed='left')): [('refugees and migrants',
#     Interval(88, 109, closed='left'))],
#   ('10,346',
#    Interval(111, 117, closed='left')): [('refugees and migrants',
#     Interval(88, 109, closed='left')), ('men',
#     Interval(118, 121, closed='left'))],
#   ('2,172',
#    Interval(123, 128, closed='left')): [('refugees and migrants',
#     Interval(88, 109, closed='left')), ('women',
#     Interval(129, 134, closed='left'))],
#   ('1,421',
#    Interval(139, 144, closed='left')): [('refugees and migrants',
#     Interval(88, 109, closed='left')), ('children',
#     Interval(145, 153, closed='left'))],
#   ('2,162',
#    Interval(262, 267, closed='left')): [('refugees and migrants',
#     Interval(218, 239, closed='left')), ('individuals',
#     Interval(268, 279, closed='left'))],
#   ('3,453',
#    Interval(350, 355, closed='left')): [('refugees and migrants',
#     Interval(218, 239, closed='left')), ('individuals',
#     Interval(356, 367, closed='left'))],
#   ('2,167',
#    Interval(379, 384, closed='left')): [('refugees and migrants',
#     Interval(218, 239, closed='left')), ('individuals',
#     Interval(385, 396, closed='left'))],
#   ('546',
#    Interval(412, 415, closed='left')): [('individuals',
#     Interval(416, 427, closed='left'))],
#   ('27',
#    Interval(500, 502, closed='left')): [('individuals',
#     Interval(503, 514, closed='left'))],
#   ('110',
#    Interval(574, 577, closed='left')): [('individuals',
#     Interval(578, 589, closed='left'))]},
#  'a1a2_352039': {('one',
#    Interval(83, 86, closed='left')): [('laboratory',
#     Interval(87, 97, closed='left'))],
#   ('one',
#    Interval(101, 104, closed='left')): [('government-run hospital',
#     Interval(105, 128, closed='left'))],
#   ('15',
#    Interval(197, 199, closed='left')): [('coronavirus tests',
#     Interval(200, 217, closed='left'))],
#   ('500',
#    Interval(447, 450, closed='left')): [('coronavirus tests',
#     Interval(451, 468, closed='left'))]},
#  'a1_363350': {('756',
#    Interval(120, 123, closed='left')): [('SYP per kg',
#     Interval(124, 134, closed='left'))],
#   ('29 percent',
#    Interval(221, 231, closed='left')): [('m-o-m',
#     Interval(232, 237, closed='left'))],
#   ('475',
#    Interval(568, 571, closed='left')): [('SYP per kg',
#     Interval(572, 582, closed='left'))],
#   ('34 percent',
#    Interval(584, 594, closed='left')): [('m-o-m',
#     Interval(595, 600, closed='left'))],
#   ('800',
#    Interval(671, 674, closed='left')): [('SYP',
#     Interval(675, 678, closed='left'))],
#   ('756',
#    Interval(696, 699, closed='left')): [('SYP',
#     Interval(700, 703, closed='left'))],
#   ('20 percent',
#    Interval(758, 768, closed='left')): [('m-om',
#     Interval(769, 773, closed='left'))],
#   ('one',
#    Interval(787, 790, closed='left')): [('kilogram of tomatoes',
#     Interval(791, 811, closed='left'))],
#   ('630',
#    Interval(827, 830, closed='left')): [('SYP per kg',
#     Interval(831, 841, closed='left'))]},
#  'a1a3_11483': {('five',
#    Interval(245, 249, closed='left')): [('reported incidents',
#     Interval(250, 268, closed='left'))],
#   ('55 per cent',
#    Interval(272, 283, closed='left')): [('reported incidents',
#     Interval(250, 268, closed='left'))],
#   ('five',
#    Interval(317, 321, closed='left')): [('incidents were caused by airstrikes',
#     Interval(322, 357, closed='left'))],
#   ('four',
#    Interval(377, 381, closed='left')): [('civilian casualties',
#     Interval(382, 401, closed='left'))],
#   ('112',
#    Interval(445, 448, closed='left')): [('casualties',
#     Interval(449, 459, closed='left'))],
#   ('100',
#    Interval(589, 592, closed='left')): [('households',
#     Interval(593, 603, closed='left'))],
#   ('2,000',
#    Interval(746, 751, closed='left')): [('households',
#     Interval(752, 762, closed='left'))]},
#  'a1a2_57316': {('15,000',
#    Interval(331, 337, closed='left')): [('host community',
#     Interval(338, 352, closed='left'))],
#   ('800',
#    Interval(368, 371, closed='left')): [('migrant children',
#     Interval(372, 388, closed='left'))],
#   ('50:50',
#    Interval(390, 395, closed='left')): [('boys/girls',
#     Interval(396, 406, closed='left'))]},
#  'a3_104965': {('two',
#    Interval(138, 141, closed='left')): [('month',
#     Interval(142, 147, closed='left'))],
#   ('7',
#    Interval(320, 321, closed='left')): [('month',
#     Interval(322, 327, closed='left'))],
#   ('25,913',
#    Interval(452, 458, closed='left')): [('cases pending adjudication',
#     Interval(422, 448, closed='left'))]},
#  'a3_385303': {('two',
#    Interval(309, 312, closed='left')): [('locationss',
#     Interval(313, 323, closed='left'))],
#   ('140',
#    Interval(645, 648, closed='left')): [('kilometer',
#     Interval(649, 658, closed='left'))]},
#  'a2_75113': {},
#  'a1a3_25314': {('twenty-three',
#    Interval(32, 44, closed='left')): [('Boko Haram militants',
#     Interval(45, 65, closed='left'))],
#   ('two',
#    Interval(124, 127, closed='left')): [('deaths',
#     Interval(128, 134, closed='left'))],
#   ('one',
#    Interval(164, 167, closed='left')): [('death',
#     Interval(168, 173, closed='left'))],
#   ('one',
#    Interval(234, 237, closed='left')): [('death',
#     Interval(238, 243, closed='left'))],
#   ('two',
#    Interval(264, 267, closed='left')): [('deaths',
#     Interval(268, 274, closed='left'))],
#   ('four',
#    Interval(305, 309, closed='left')): [('deaths',
#     Interval(310, 316, closed='left'))],
#   ('twenty',
#    Interval(387, 393, closed='left')): [('Independent National Electoral Commission (INEC) ad hoc staff',
#     Interval(394, 455, closed='left'))],
#   ('one',
#    Interval(516, 519, closed='left')): [('death',
#     Interval(520, 525, closed='left'))],
#   ('two',
#    Interval(587, 590, closed='left')): [('deaths',
#     Interval(591, 597, closed='left'))],
#   ('four',
#    Interval(626, 630, closed='left')): [('deaths',
#     Interval(631, 637, closed='left'))],
#   ('one',
#    Interval(699, 702, closed='left')): [('death',
#     Interval(703, 708, closed='left'))],
#   ('two',
#    Interval(774, 777, closed='left')): [('deaths',
#     Interval(778, 784, closed='left'))],
#   ('Six',
#    Interval(821, 824, closed='left')): [('INEC staff',
#     Interval(825, 835, closed='left'))],
#   ('two',
#    Interval(989, 992, closed='left')): [('deaths',
#     Interval(993, 999, closed='left'))],
#   ('one',
#    Interval(1056, 1059, closed='left')): [('death',
#     Interval(1060, 1065, closed='left'))],
#   ('one',
#    Interval(1131, 1134, closed='left')): [('death',
#     Interval(1135, 1140, closed='left'))],
#   ('four',
#    Interval(1182, 1186, closed='left')): [('killed',
#     Interval(1175, 1181, closed='left'))],
#   ('five',
#    Interval(1225, 1229, closed='left')): [('kidnapped',
#     Interval(1191, 1200, closed='left'))],
#   ('one',
#    Interval(1287, 1290, closed='left')): [('death',
#     Interval(1291, 1296, closed='left'))],
#   ('two',
#    Interval(1317, 1320, closed='left')): [('deaths',
#     Interval(1321, 1327, closed='left'))],
#   ('one',
#    Interval(1372, 1375, closed='left')): [('killed',
#     Interval(1365, 1371, closed='left'))],
#   ('one',
#    Interval(1435, 1438, closed='left')): [('death',
#     Interval(1439, 1444, closed='left'))],
#   ('five',
#    Interval(1495, 1499, closed='left')): [('sailors off the coast',
#     Interval(1500, 1521, closed='left'))]},
#  'a2_62075': {('60 percent', Interval(93, 103, closed='left')): [],
#   ('eleven',
#    Interval(573, 579, closed='left')): [('years',
#     Interval(580, 585, closed='left'))],
#   ('70 percent', Interval(659, 669, closed='left')): [],
#   ('80 percent',
#    Interval(885, 895, closed='left')): [('households',
#     Interval(899, 909, closed='left'))]},
#  'a2_357797': {('115, 051',
#    Interval(380, 388, closed='left')): [('children',
#     Interval(389, 397, closed='left'))],
#   ('59,510',
#    Interval(406, 412, closed='left')): [('girls',
#     Interval(399, 404, closed='left'))],
#   ('55,541',
#    Interval(420, 426, closed='left')): [('boys',
#     Interval(414, 418, closed='left'))],
#   ('112, 544',
#    Interval(503, 511, closed='left')): [('children',
#     Interval(512, 520, closed='left'))],
#   ('1004',
#    Interval(582, 586, closed='left')): [('unaccompanied, separated and children',
#     Interval(587, 624, closed='left'))],
#   ('1, 885',
#    Interval(705, 711, closed='left')): [('child beneficiaries',
#     Interval(712, 731, closed='left'))],
#   ('23, 155',
#    Interval(772, 779, closed='left')): [('children/adolescents',
#     Interval(780, 800, closed='left'))]},
#  'a2_13554': {('200',
#    Interval(281, 284, closed='left')): [('families',
#     Interval(285, 293, closed='left'))],
#   ('5',
#    Interval(310, 311, closed='left')): [('schools',
#     Interval(312, 319, closed='left'))]},
#  'a2a3_275581': {('4,000',
#    Interval(141, 146, closed='left')): [('schools',
#     Interval(147, 154, closed='left'))],
#   ('700,000',
#    Interval(189, 196, closed='left')): [('students',
#     Interval(197, 205, closed='left'))],
#   ('30 percent',
#    Interval(493, 503, closed='left')): [('children',
#     Interval(521, 529, closed='left'))]},
#  'a1_241237': {('25',
#    Interval(232, 234, closed='left')): [('hand pumps',
#     Interval(235, 245, closed='left'))],
#   ('14',
#    Interval(256, 258, closed='left')): [('hand pumps',
#     Interval(235, 245, closed='left'))],
#   ('7',
#    Interval(268, 269, closed='left')): [('hand pumps',
#     Interval(235, 245, closed='left'))],
#   ('4',
#    Interval(283, 284, closed='left')): [('hand pumps',
#     Interval(235, 245, closed='left'))],
#   ('24',
#    Interval(327, 329, closed='left')): [('hand pumps',
#     Interval(330, 340, closed='left'))],
#   ('eight',
#    Interval(361, 366, closed='left')): [('hand pumps',
#     Interval(330, 340, closed='left'))],
#   ('75%%',
#    Interval(374, 378, closed='left')): [('hand pumps',
#     Interval(330, 340, closed='left'))],
#   ('5',
#    Interval(458, 459, closed='left')): [('hand pumps',
#     Interval(330, 340, closed='left'))],
#   ('2',
#    Interval(474, 475, closed='left')): [('hand pumps',
#     Interval(330, 340, closed='left'))],
#   ('2',
#    Interval(490, 491, closed='left')): [('hand pumps',
#     Interval(330, 340, closed='left'))],
#   ('5',
#    Interval(506, 507, closed='left')): [('hand pumps',
#     Interval(330, 340, closed='left'))],
#   ('2',
#    Interval(526, 527, closed='left')): [('hand pumps',
#     Interval(330, 340, closed='left'))],
#   ('12',
#    Interval(546, 548, closed='left')): [('mechanized water points',
#     Interval(549, 572, closed='left'))],
#   ('5',
#    Interval(628, 629, closed='left')): [('mechanized water points',
#     Interval(549, 572, closed='left'))],
#   ('2',
#    Interval(641, 642, closed='left')): [('mechanized water points',
#     Interval(549, 572, closed='left'))],
#   ('2',
#    Interval(657, 658, closed='left')): [('mechanized water points',
#     Interval(549, 572, closed='left'))],
#   ('2',
#    Interval(673, 674, closed='left')): [('mechanized water points',
#     Interval(549, 572, closed='left'))],
#   ('1',
#    Interval(693, 694, closed='left')): [('mechanized water points',
#     Interval(549, 572, closed='left'))]},
#  'a3_287956': {('130',
#    Interval(94, 97, closed='left')): [('systems',
#     Interval(122, 129, closed='left'))],
#   ('130 out of 200',
#    Interval(94, 108, closed='left')): [('systems',
#     Interval(122, 129, closed='left'))],
#   ('200',
#    Interval(105, 108, closed='left')): [('systems',
#     Interval(122, 129, closed='left'))],
#   ('65 percent',
#    Interval(110, 120, closed='left')): [('systems',
#     Interval(122, 129, closed='left'))],
#   ('138',
#    Interval(143, 146, closed='left')): [('systems',
#     Interval(171, 178, closed='left'))],
#   ('138 out of 244',
#    Interval(143, 157, closed='left')): [('systems',
#     Interval(171, 178, closed='left'))],
#   ('244',
#    Interval(154, 157, closed='left')): [('systems',
#     Interval(171, 178, closed='left'))],
#   ('56 percent',
#    Interval(159, 169, closed='left')): [('systems',
#     Interval(171, 178, closed='left'))],
#   ('15 percent',
#    Interval(223, 233, closed='left')): [('stations',
#     Interval(241, 249, closed='left'))],
#   ('16 percent',
#    Interval(264, 274, closed='left')): [('stations',
#     Interval(282, 290, closed='left'))],
#   ('30 per cent',
#    Interval(487, 498, closed='left')): [('total WASH cluster expenditure.',
#     Interval(506, 537, closed='left'))]},
#  'a3_338882': {('1,260',
#    Interval(130, 135, closed='left')): [('households',
#     Interval(136, 146, closed='left'))],
#   ('7,411',
#    Interval(148, 153, closed='left')): [('persons',
#     Interval(154, 161, closed='left'))],
#   ('1,710',
#    Interval(201, 206, closed='left')): [('men',
#     Interval(207, 210, closed='left'))],
#   ('2,461',
#    Interval(212, 217, closed='left')): [('women',
#     Interval(218, 223, closed='left'))],
#   ('1, 411',
#    Interval(225, 231, closed='left')): [('boys',
#     Interval(232, 236, closed='left'))],
#   ('1,829',
#    Interval(241, 246, closed='left')): [('girls',
#     Interval(247, 252, closed='left'))],
#   ('10',
#    Interval(572, 574, closed='left')): [('jingles per day in Radio Nigeria Fombina FM',
#     Interval(575, 618, closed='left'))],
#   ('10',
#    Interval(620, 622, closed='left')): [('jingles per day by Gotel Radio',
#     Interval(623, 653, closed='left'))],
#   ('10',
#    Interval(655, 657, closed='left')): [('jingles per day by ABC Radio',
#     Interval(658, 686, closed='left'))],
#   ('5',
#    Interval(688, 689, closed='left')): [('jingles per day by Pulaako FM',
#     Interval(690, 719, closed='left'))],
#   ('5',
#    Interval(724, 725, closed='left')): [('TV jingles per day in Adamawa State Television',
#     Interval(726, 772, closed='left'))]},
#  'a1_241888': {('3,900',
#    Interval(274, 279, closed='left')): [('USD/LBP',
#     Interval(266, 273, closed='left'))],
#   ('half',
#    Interval(288, 292, closed='left')): [('retailers',
#     Interval(56, 65, closed='left'))],
#   ('8,000',
#    Interval(331, 336, closed='left')): [('USD/LBP',
#     Interval(323, 330, closed='left'))],
#   ('Eighty-four percent',
#    Interval(394, 413, closed='left')): [('retailers',
#     Interval(56, 65, closed='left'))],
#   ('3,900',
#    Interval(547, 552, closed='left')): [('LBP',
#     Interval(544, 547, closed='left')), ('/USD',
#     Interval(552, 556, closed='left'))],
#   ('two percent', Interval(682, 693, closed='left')): []},
#  'a2a3_310409': {('80 percent',
#    Interval(123, 133, closed='left')): [('Rohingya households',
#     Interval(137, 156, closed='left'))],
#   ('40 percent',
#    Interval(161, 171, closed='left')): [('host community households',
#     Interval(175, 200, closed='left'))],
#   ('7 percent', Interval(300, 309, closed='left')): []},
#  'a1_316396': {('one',
#    Interval(98, 101, closed='left')): [('jobs in private businesses',
#     Interval(117, 143, closed='left'))],
#   ('one in five',
#    Interval(98, 109, closed='left')): [('jobs in private businesses',
#     Interval(117, 143, closed='left'))],
#   ('five',
#    Interval(105, 109, closed='left')): [('jobs in private businesses',
#     Interval(117, 143, closed='left'))],
#   ('three',
#    Interval(377, 382, closed='left')): [('NGOs',
#     Interval(391, 395, closed='left'))],
#   ('three in four',
#    Interval(377, 390, closed='left')): [('NGOs',
#     Interval(391, 395, closed='left'))],
#   ('four',
#    Interval(386, 390, closed='left')): [('NGOs',
#     Interval(391, 395, closed='left'))],
#   ('76%',
#    Interval(397, 400, closed='left')): [('NGOs',
#     Interval(391, 395, closed='left'))],
#   ('one',
#    Interval(476, 479, closed='left')): [('NGOs',
#     Interval(391, 395, closed='left'))],
#   ('one in five',
#    Interval(476, 487, closed='left')): [('NGOs',
#     Interval(391, 395, closed='left'))],
#   ('five',
#    Interval(483, 487, closed='left')): [('NGOs',
#     Interval(391, 395, closed='left'))],
#   ('half',
#    Interval(528, 532, closed='left')): [('NGOs',
#     Interval(391, 395, closed='left'))],
#   ('21%', Interval(534, 537, closed='left')): [],
#   ('5%',
#    Interval(540, 542, closed='left')): [('NGOs',
#     Interval(391, 395, closed='left'))],
#   ('18%',
#    Interval(576, 579, closed='left')): [('NGOs',
#     Interval(391, 395, closed='left'))],
#   ('87%',
#    Interval(675, 678, closed='left')): [('NGOs',
#     Interval(603, 607, closed='left'))],
#   ('2%',
#    Interval(697, 699, closed='left')): [('NGOs',
#     Interval(603, 607, closed='left'))]},
#  'a2_11626': {('five',
#    Interval(156, 160, closed='left')): [('basic commodities',
#     Interval(161, 178, closed='left'))],
#   ('2 billion',
#    Interval(237, 246, closed='left')): [('$',
#     Interval(236, 237, closed='left'))]},
#  'a2_85701': {('one',
#    Interval(2259, 2262, closed='left')): [('hospital',
#     Interval(2263, 2271, closed='left'))],
#   ('two',
#    Interval(2280, 2283, closed='left')): [('doctors',
#     Interval(2284, 2291, closed='left'))],
#   ('one and a half',
#    Interval(2347, 2361, closed='left')): [('years',
#     Interval(2362, 2367, closed='left'))],
#   ('one',
#    Interval(2432, 2435, closed='left')): [('female doctor',
#     Interval(2436, 2449, closed='left'))],
#   ('15',
#    Interval(2509, 2511, closed='left')): [('Venezuelan women',
#     Interval(2512, 2528, closed='left'))],
#   ('two',
#    Interval(2800, 2803, closed='left')): [('confirmed cases of multidrug resistant tuberculosis',
#     Interval(2804, 2855, closed='left'))]},
#  'a3_281963': {('4,638',
#    Interval(58, 63, closed='left')): [('people',
#     Interval(64, 70, closed='left'))],
#   ('22%',
#    Interval(229, 232, closed='left')): [('people',
#     Interval(64, 70, closed='left'))],
#   ('7%',
#    Interval(331, 333, closed='left')): [('people',
#     Interval(64, 70, closed='left'))]},
#  'a1_159767': {('seven',
#    Interval(155, 160, closed='left')): [('LGAs',
#     Interval(161, 165, closed='left'))],
#   ('49',
#    Interval(170, 172, closed='left')): [('camps',
#     Interval(173, 178, closed='left'))],
#   ('83,000',
#    Interval(184, 190, closed='left')): [('households',
#     Interval(191, 201, closed='left'))]},
#  'a1_272248': {('40 percent',
#    Interval(67, 77, closed='left')): [('Unemployment',
#     Interval(29, 41, closed='left'))],
#   ('33.5 percent',
#    Interval(204, 216, closed='left')): [('unemployment',
#     Interval(166, 178, closed='left'))],
#   ('23 percent',
#    Interval(231, 241, closed='left')): [('unemployment',
#     Interval(166, 178, closed='left'))],
#   ('one third',
#    Interval(276, 285, closed='left')): [('jobs',
#     Interval(289, 293, closed='left'))],
#   ('4',
#    Interval(585, 586, closed='left')): [('workers',
#     Interval(593, 600, closed='left'))],
#   ('4 in 10',
#    Interval(585, 592, closed='left')): [('workers',
#     Interval(593, 600, closed='left'))],
#   ('10',
#    Interval(590, 592, closed='left')): [('workers',
#     Interval(593, 600, closed='left'))]},
#  'a1_313779': {('166',
#    Interval(454, 457, closed='left')): [('households',
#     Interval(458, 468, closed='left'))],
#   ('1,860',
#    Interval(472, 477, closed='left')): [('individuals',
#     Interval(478, 489, closed='left'))]},
#  'a3_102620': {('Two',
#    Interval(0, 3, closed='left')): [('new confirmed cases',
#     Interval(8, 27, closed='left'))],
#   ('one',
#    Interval(49, 52, closed='left')): [('case',
#     Interval(57, 61, closed='left'))],
#   ('forty-nine (49)',
#    Interval(152, 167, closed='left')): [('confirmed COVID-19 case(s)',
#     Interval(117, 143, closed='left'))],
#   ('Twenty (20)',
#    Interval(169, 180, closed='left')): [('cases',
#     Interval(181, 186, closed='left'))],
#   ('eleven (11)',
#    Interval(202, 213, closed='left')): [('cases',
#     Interval(214, 219, closed='left')), ('cases',
#     Interval(214, 219, closed='left'))],
#   ('nine (9)',
#    Interval(232, 240, closed='left')): [('cases',
#     Interval(241, 246, closed='left')), ('cases',
#     Interval(241, 246, closed='left'))],
#   ('three (3)',
#    Interval(258, 267, closed='left')): [('cases',
#     Interval(268, 273, closed='left'))],
#   ('one (1)',
#    Interval(293, 300, closed='left')): [('case',
#     Interval(301, 305, closed='left')), ('case',
#     Interval(301, 305, closed='left'))],
#   ('thirteen (13)',
#    Interval(459, 472, closed='left')): [('Health Care Workers (HCWs)',
#     Interval(416, 442, closed='left'))],
#   ('Seven (7)',
#    Interval(474, 483, closed='left')): [('nurses',
#     Interval(484, 490, closed='left'))],
#   ('four (4)',
#    Interval(492, 500, closed='left')): [('doctors',
#     Interval(501, 508, closed='left'))],
#   ('one (1)',
#    Interval(510, 517, closed='left')): [('physiotherapist',
#     Interval(518, 533, closed='left'))],
#   ('one (1)',
#    Interval(539, 546, closed='left')): [('laboratory scientist',
#     Interval(547, 567, closed='left'))],
#   ('six (6)',
#    Interval(629, 636, closed='left')): [('deaths due to COVID-19',
#     Interval(590, 612, closed='left'))]},
#  'a2_193683': {('4',
#    Interval(123, 124, closed='left')): [('health districts',
#     Interval(125, 141, closed='left'))],
#   ('5',
#    Interval(196, 197, closed='left')): [('health districts',
#     Interval(198, 214, closed='left'))],
#   ('6,485',
#    Interval(277, 282, closed='left')): [('children',
#     Interval(283, 291, closed='left'))],
#   ('3,995',
#    Interval(337, 342, closed='left')): [('children',
#     Interval(343, 351, closed='left'))],
#   ('3,352',
#    Interval(383, 388, closed='left')): [('children',
#     Interval(389, 397, closed='left'))],
#   ('3,369',
#    Interval(423, 428, closed='left')): [('children',
#     Interval(429, 437, closed='left'))],
#   ('718',
#    Interval(464, 467, closed='left')): [('children',
#     Interval(468, 476, closed='left'))],
#   ('1,557',
#    Interval(494, 499, closed='left')): [('children',
#     Interval(500, 508, closed='left'))],
#   ('1,886',
#    Interval(558, 563, closed='left')): [('children',
#     Interval(564, 572, closed='left'))],
#   ('2,069',
#    Interval(613, 618, closed='left')): [('pregnant women',
#     Interval(619, 633, closed='left'))],
#   ('401',
#    Interval(677, 680, closed='left')): [('pregnant women',
#     Interval(681, 695, closed='left'))]},
#  'a2_310991': {('735',
#    Interval(534, 537, closed='left')): [('BDT',
#     Interval(530, 533, closed='left')), ('per capita',
#     Interval(538, 548, closed='left'))],
#   ('9',
#    Interval(554, 555, closed='left')): [('USD',
#     Interval(550, 553, closed='left'))],
#   ('2378',
#    Interval(595, 599, closed='left')): [('BDT',
#     Interval(591, 594, closed='left')), ('per capita',
#     Interval(600, 610, closed='left'))],
#   ('28',
#    Interval(616, 618, closed='left')): [('USD',
#     Interval(612, 615, closed='left'))],
#   ('1908',
#    Interval(728, 732, closed='left')): [('BDT',
#     Interval(724, 727, closed='left')), ('/capita/month',
#     Interval(732, 745, closed='left'))],
#   ('23',
#    Interval(751, 753, closed='left')): [('(USD',
#     Interval(746, 750, closed='left'))]},
#  'a2_179271': {('55 percent', Interval(512, 522, closed='left')): [],
#   ('40 percent', Interval(780, 790, closed='left')): [],
#   ('60 percent', Interval(932, 942, closed='left')): [],
#   ('2.2 million',
#    Interval(1392, 1403, closed='left')): [('tonnes',
#     Interval(1404, 1410, closed='left'))],
#   ('4.5 million',
#    Interval(1465, 1476, closed='left')): [('tonnes',
#     Interval(1477, 1483, closed='left'))],
#   ('3.5 million',
#    Interval(1494, 1505, closed='left')): [('tonnes',
#     Interval(1506, 1512, closed='left'))],
#   ('4.1 million',
#    Interval(1544, 1555, closed='left')): [('tonnes',
#     Interval(1556, 1562, closed='left'))],
#   ('2.8 million',
#    Interval(1690, 1701, closed='left')): [('tonnes',
#     Interval(1702, 1708, closed='left'))],
#   ('0.8 million',
#    Interval(1726, 1737, closed='left')): [('tonnes',
#     Interval(1738, 1744, closed='left'))],
#   ('50 percent',
#    Interval(1855, 1865, closed='left')): [('Syrians',
#     Interval(1869, 1876, closed='left'))],
#   ('89 percent',
#    Interval(1998, 2008, closed='left')): [('Syrians',
#     Interval(2012, 2019, closed='left'))]},
#  'a1a2_160839': {('31',
#    Interval(39, 41, closed='left')): [('informal sites',
#     Interval(42, 56, closed='left'))],
#   ('30 per cent',
#    Interval(168, 179, closed='left')): [('increase in evictions',
#     Interval(141, 162, closed='left'))],
#   ('50 per cent',
#    Interval(183, 194, closed='left')): [('increase in evictions',
#     Interval(141, 162, closed='left'))],
#   ('six',
#    Interval(220, 223, closed='left')): [('cases',
#     Interval(224, 229, closed='left'))],
#   ('one',
#    Interval(279, 282, closed='left')): [('month',
#     Interval(283, 288, closed='left'))],
#   ('one',
#    Interval(315, 318, closed='left')): [('cases',
#     Interval(326, 331, closed='left'))],
#   ('two',
#    Interval(322, 325, closed='left')): [('cases',
#     Interval(326, 331, closed='left'))]},
#  'a2_57313': {('six',
#    Interval(203, 206, closed='left')): [('sites',
#     Interval(207, 212, closed='left'))],
#   ('70+',
#    Interval(391, 394, closed='left')): [('migrants',
#     Interval(395, 403, closed='left'))],
#   ('three',
#    Interval(443, 448, closed='left')): [('days',
#     Interval(449, 453, closed='left'))],
#   ('20',
#    Interval(529, 531, closed='left')): [('ages',
#     Interval(521, 525, closed='left'))],
#   ('20 to 40',
#    Interval(529, 537, closed='left')): [('ages',
#     Interval(521, 525, closed='left'))],
#   ('40',
#    Interval(535, 537, closed='left')): [('ages',
#     Interval(521, 525, closed='left'))]},
#  'a2_14175': {('five',
#    Interval(439, 443, closed='left')): [('days',
#     Interval(444, 448, closed='left'))],
#   ('2',
#    Interval(464, 465, closed='left')): [('kilograms',
#     Interval(466, 475, closed='left'))],
#   ('2.4',
#    Interval(511, 514, closed='left')): [('kilograms',
#     Interval(515, 524, closed='left'))],
#   ('5,210',
#    Interval(608, 613, closed='left')): [('households',
#     Interval(614, 624, closed='left'))],
#   ('4,175',
#    Interval(708, 713, closed='left')): [('households',
#     Interval(723, 733, closed='left'))],
#   ('834',
#    Interval(770, 773, closed='left')): [('households',
#     Interval(783, 793, closed='left'))]},
#  'a2_134019': {('4,266',
#    Interval(121, 126, closed='left')): [('new views',
#     Interval(127, 136, closed='left'))],
#   ('7,286', Interval(154, 159, closed='left')): [],
#   ('106',
#    Interval(577, 580, closed='left')): [('children',
#     Interval(581, 589, closed='left'))],
#   ('two',
#    Interval(656, 659, closed='left')): [('food baskets',
#     Interval(679, 691, closed='left'))]},
#  'a1_187709': {('57%',
#    Interval(508, 511, closed='left')): [('proportion of households',
#     Interval(442, 466, closed='left'))],
#   ('57% to 41%',
#    Interval(508, 518, closed='left')): [('proportion of households',
#     Interval(442, 466, closed='left'))],
#   ('41%',
#    Interval(515, 518, closed='left')): [('proportion of households',
#     Interval(442, 466, closed='left'))],
#   ('66%',
#    Interval(613, 616, closed='left')): [('proportion of households',
#     Interval(528, 552, closed='left'))],
#   ('66% to 35%',
#    Interval(613, 623, closed='left')): [('proportion of households',
#     Interval(528, 552, closed='left'))],
#   ('35%',
#    Interval(620, 623, closed='left')): [('proportion of households',
#     Interval(528, 552, closed='left'))],
#   ('12%',
#    Interval(719, 722, closed='left')): [('proportion of households',
#     Interval(635, 659, closed='left'))],
#   ('12% to 27%',
#    Interval(719, 729, closed='left')): [('proportion of households',
#     Interval(635, 659, closed='left'))],
#   ('27%',
#    Interval(726, 729, closed='left')): [('proportion of households',
#     Interval(635, 659, closed='left'))]},
#  'a3_327403': {('920',
#    Interval(96, 99, closed='left')): [('people admitted into the program',
#     Interval(100, 132, closed='left'))],
#   ('two',
#    Interval(232, 235, closed='left')): [('Boko Haram factions',
#     Interval(236, 255, closed='left'))],
#   ('thousands',
#    Interval(271, 280, closed='left')): [('people',
#     Interval(284, 290, closed='left'))],
#   ('23',
#    Interval(316, 318, closed='left')): [('former Safe Corridor internees',
#     Interval(319, 349, closed='left'))]},
#  'a3_35922': {('930',
#    Interval(39, 42, closed='left')): [('suspected cases',
#     Interval(43, 58, closed='left'))],
#   ('447 (57.8%)',
#    Interval(81, 92, closed='left')): [('LGAs',
#     Interval(93, 97, closed='left'))],
#   ('35',
#    Interval(161, 163, closed='left')): [('cases',
#     Interval(209, 214, closed='left'))],
#   ('twelve',
#    Interval(189, 195, closed='left')): [('cases',
#     Interval(209, 214, closed='left'))],
#   ('12',
#    Interval(220, 222, closed='left')): [('states',
#     Interval(223, 229, closed='left'))],
#   ('32',
#    Interval(233, 235, closed='left')): [('LGAs',
#     Interval(236, 240, closed='left'))],
#   ('12',
#    Interval(252, 254, closed='left')): [('cases',
#     Interval(265, 270, closed='left'))],
#   ('7',
#    Interval(333, 334, closed='left')): [('cases',
#     Interval(265, 270, closed='left'))],
#   ('1',
#    Interval(350, 351, closed='left')): [('cases',
#     Interval(265, 270, closed='left'))],
#   ('2',
#    Interval(372, 373, closed='left')): [('cases',
#     Interval(265, 270, closed='left'))],
#   ('1',
#    Interval(381, 382, closed='left')): [('cases',
#     Interval(265, 270, closed='left'))],
#   ('1',
#    Interval(394, 395, closed='left')): [('cases',
#     Interval(265, 270, closed='left'))],
#   ('One',
#    Interval(400, 403, closed='left')): [('yellow fever case',
#     Interval(423, 440, closed='left'))],
#   ('0.11%',
#    Interval(502, 507, closed='left')): [('Case fatality rate (CFR)',
#     Interval(474, 498, closed='left'))]},
#  'a2_336798': {('four',
#    Interval(41, 45, closed='left')): [('years',
#     Interval(46, 51, closed='left'))],
#   ('884,041',
#    Interval(261, 268, closed='left')): [('women, men, girls and boys',
#     Interval(269, 295, closed='left'))],
#   ('440,000',
#    Interval(324, 331, closed='left')): [('Rohingya children',
#     Interval(332, 349, closed='left'))]},
#  'a1_166931': {('100 per cent',
#    Interval(339, 351, closed='left')): [('online',
#     Interval(352, 358, closed='left'))],
#   ('850',
#    Interval(529, 532, closed='left')): [('children',
#     Interval(533, 541, closed='left'))],
#   ('30 per cent',
#    Interval(543, 554, closed='left')): [('children',
#     Interval(533, 541, closed='left'))]},
#  'a3_185667': {('8\nmillion',
#    Interval(473, 482, closed='left')): [('people',
#     Interval(483, 489, closed='left'))],
#   ('3.3 million',
#    Interval(577, 588, closed='left')): [('people',
#     Interval(589, 595, closed='left'))],
#   ('750,000',
#    Interval(636, 643, closed='left')): [('people',
#     Interval(644, 650, closed='left'))]},
#  'a2_224705': {('182,341',
#    Interval(436, 443, closed='left')): [('people (displaced persons, refugees, returnees)',
#     Interval(444, 491, closed='left'))],
#   ('325',
#    Interval(524, 527, closed='left')): [('g of cereals',
#     Interval(528, 540, closed='left'))],
#   ('72',
#    Interval(542, 544, closed='left')): [('g of pulses',
#     Interval(545, 556, closed='left'))],
#   ('23',
#    Interval(561, 563, closed='left')): [('g of oil',
#     Interval(564, 572, closed='left'))],
#   ('3,500',
#    Interval(603, 608, closed='left')): [('XAF',
#     Interval(599, 602, closed='left')), ('per person per month',
#     Interval(609, 629, closed='left'))],
#   ('6,000',
#    Interval(666, 671, closed='left')): [('XAF',
#     Interval(662, 665, closed='left')), ('per person per month',
#     Interval(672, 692, closed='left'))]},
#  'a2_291034': {('76%',
#    Interval(10, 13, closed='left')): [('[households] HHs',
#     Interval(17, 33, closed='left')), ('children aged 4-16 years',
#     Interval(39, 63, closed='left'))],
#   ('4',
#    Interval(53, 54, closed='left')): [('years',
#     Interval(58, 63, closed='left'))],
#   ('4-16',
#    Interval(53, 57, closed='left')): [('years',
#     Interval(58, 63, closed='left'))],
#   ('16',
#    Interval(55, 57, closed='left')): [('years',
#     Interval(58, 63, closed='left'))],
#   ('76%',
#    Interval(65, 68, closed='left')): [('HHs',
#     Interval(78, 81, closed='left'))],
#   ('4',
#    Interval(134, 135, closed='left')): [('days/week',
#     Interval(136, 145, closed='left'))],
#   ('77%',
#    Interval(260, 263, closed='left')): [('Non-displaced',
#     Interval(245, 258, closed='left'))],
#   ('62%',
#    Interval(271, 274, closed='left')): [('IDP',
#     Interval(266, 269, closed='left'))],
#   ('49%',
#    Interval(286, 289, closed='left')): [('Refugee',
#     Interval(277, 284, closed='left'))],
#   ('98%', Interval(321, 324, closed='left')): [],
#   ('40%', Interval(494, 497, closed='left')): [],
#   ('72%', Interval(555, 558, closed='left')): []},
#  'a2_225143': {('18',
#    Interval(626, 628, closed='left')): [('LGAs',
#     Interval(635, 639, closed='left'))],
#   ('27',
#    Interval(632, 634, closed='left')): [('LGAs',
#     Interval(635, 639, closed='left'))]},
#  'a1_1871': {('100 per cent',
#    Interval(62, 74, closed='left')): [('urban communities',
#     Interval(78, 95, closed='left'))],
#   ('95 per cent',
#    Interval(100, 111, closed='left')): [('rural populations',
#     Interval(115, 132, closed='left'))],
#   ('60 per cent',
#    Interval(168, 179, closed='left')): [('urban areas',
#     Interval(183, 194, closed='left'))],
#   ('40 per cent',
#    Interval(199, 210, closed='left')): [('rural areas',
#     Interval(214, 225, closed='left'))],
#   ('Six',
#    Interval(230, 233, closed='left')): [('years',
#     Interval(234, 239, closed='left'))],
#   ('64 per cent',
#    Interval(293, 304, closed='left')): [('affected population',
#     Interval(314, 333, closed='left'))],
#   ('4',
#    Interval(413, 414, closed='left')): [('hours',
#     Interval(417, 422, closed='left'))],
#   ('4-5',
#    Interval(413, 416, closed='left')): [('hours',
#     Interval(417, 422, closed='left'))],
#   ('5',
#    Interval(415, 416, closed='left')): [('hours',
#     Interval(417, 422, closed='left'))],
#   ('14',
#    Interval(451, 453, closed='left')): [('hours',
#     Interval(454, 459, closed='left'))],
#   ('43 per cent',
#    Interval(723, 734, closed='left')): [('affected population',
#     Interval(742, 761, closed='left'))]},
#  'a1a3_241887': {('588,043',
#    Interval(291, 298, closed='left')): [('tons of wheat',
#     Interval(299, 312, closed='left'))],
#   ('227,471',
#    Interval(375, 382, closed='left')): [('tons of wheat',
#     Interval(383, 396, closed='left'))],
#   ('173,490',
#    Interval(410, 417, closed='left')): [('tons',
#     Interval(418, 422, closed='left'))],
#   ('31 percent', Interval(454, 464, closed='left')): [],
#   ('Thirty-six percent',
#    Interval(883, 901, closed='left')): [('stores',
#     Interval(905, 911, closed='left'))],
#   ('two',
#    Interval(959, 962, closed='left')): [('weeks',
#     Interval(963, 968, closed='left'))],
#   ('18 percent',
#    Interval(1006, 1016, closed='left')): [('national average',
#     Interval(986, 1002, closed='left'))]},
#  'a1_281962': {('4,638',
#    Interval(58, 63, closed='left')): [('people',
#     Interval(64, 70, closed='left'))],
#   ('46%',
#    Interval(486, 489, closed='left')): [('respondents',
#     Interval(493, 504, closed='left'))],
#   ('20%',
#    Interval(575, 578, closed='left')): [('respondents',
#     Interval(493, 504, closed='left'))],
#   ('76%',
#    Interval(650, 653, closed='left')): [('respondents',
#     Interval(657, 668, closed='left'))]},
#  'a1_167386': {('10',
#    Interval(96, 98, closed='left')): [('CFS',
#     Interval(99, 102, closed='left'))],
#   ('8',
#    Interval(170, 171, closed='left')): [('CFS',
#     Interval(99, 102, closed='left'))]},
#  'a1a3_264773': {('63.5 percent',
#    Interval(113, 125, closed='left')): [('of all households',
#     Interval(126, 143, closed='left'))],
#   ('17.6 percent',
#    Interval(232, 244, closed='left')): [('all households',
#     Interval(245, 259, closed='left'))],
#   ('30 percent',
#    Interval(303, 313, closed='left')): [('all households',
#     Interval(245, 259, closed='left'))],
#   ('15.9 percent',
#    Interval(339, 351, closed='left')): [('all households',
#     Interval(245, 259, closed='left'))],
#   ('35 percent',
#    Interval(417, 427, closed='left')): [('all households',
#     Interval(431, 445, closed='left'))],
#   ('1.8 percent',
#    Interval(517, 528, closed='left')): [('all households',
#     Interval(431, 445, closed='left'))],
#   ('four percent',
#    Interval(582, 594, closed='left')): [('households',
#     Interval(598, 608, closed='left'))],
#   ('60 percent',
#    Interval(638, 648, closed='left')): [('households',
#     Interval(652, 662, closed='left'))]},
#  'a2_17511': {('40 thousand',
#    Interval(662, 673, closed='left')): [('mines',
#     Interval(674, 679, closed='left'))],
#   ('200 thousand',
#    Interval(767, 779, closed='left')): [('mines',
#     Interval(739, 744, closed='left'))],
#   ('226209',
#    Interval(788, 794, closed='left')): [('mines, explosive devices, and shells',
#     Interval(795, 831, closed='left'))]},
#  'a2_80876': {('3,000',
#    Interval(93, 98, closed='left')): [('government registration cards',
#     Interval(99, 128, closed='left'))],
#   ('16,523',
#    Interval(132, 138, closed='left')): [('adults',
#     Interval(139, 145, closed='left'))],
#   ('2,421',
#    Interval(150, 155, closed='left')): [('children Venezuelans',
#     Interval(156, 176, closed='left'))],
#   ('two',
#    Interval(208, 211, closed='left')): [('week',
#     Interval(212, 216, closed='left'))],
#   ('six',
#    Interval(403, 406, closed='left')): [('months',
#     Interval(407, 413, closed='left'))]},
#  'a1a3_37730': {('Four',
#    Interval(91, 95, closed='left')): [('LGAs',
#     Interval(96, 100, closed='left'))],
#   ('five',
#    Interval(501, 505, closed='left')): [('children',
#     Interval(486, 494, closed='left'))],
#   ('263',
#    Interval(544, 547, closed='left')): [('children',
#     Interval(559, 567, closed='left'))],
#   ('460',
#    Interval(555, 558, closed='left')): [('children',
#     Interval(559, 567, closed='left'))]},
#  'a2_190106': {('87.6%',
#    Interval(72, 77, closed='left')): [('students',
#     Interval(82, 90, closed='left'))],
#   ('53.4%', Interval(156, 161, closed='left')): [],
#   ('15%',
#    Interval(631, 634, closed='left')): [('students',
#     Interval(621, 629, closed='left'))]},
#  'a3_83995': {('1.84 million',
#    Interval(10, 22, closed='left')): [('people',
#     Interval(23, 29, closed='left'))],
#   ('1,483,566',
#    Interval(320, 329, closed='left')): [('IDPs',
#     Interval(314, 318, closed='left'))]},
#  'a3_271261': {('3,364',
#    Interval(74, 79, closed='left')): [('health care sector personnel',
#     Interval(80, 108, closed='left'))],
#   ('3,329',
#    Interval(219, 224, closed='left')): [('health care sector personnel',
#     Interval(80, 108, closed='left'))],
#   ('99%',
#    Interval(287, 290, closed='left')): [('arrests and enforced disappearances',
#     Interval(298, 333, closed='left'))],
#   ('744',
#    Interval(647, 650, closed='left')): [('arrests/detention',
#     Interval(611, 628, closed='left'))],
#   ('387',
#    Interval(669, 672, closed='left')): [('arrests/detention',
#     Interval(611, 628, closed='left'))],
#   ('373',
#    Interval(683, 686, closed='left')): [('arrests/detention',
#     Interval(611, 628, closed='left'))],
#   ('288',
#    Interval(695, 698, closed='left')): [('arrests/detention',
#     Interval(611, 628, closed='left'))],
#   ('257',
#    Interval(710, 713, closed='left')): [('arrests/detention',
#     Interval(611, 628, closed='left'))],
#   ('647',
#    Interval(813, 816, closed='left')): [('arrested or detained',
#     Interval(791, 811, closed='left'))],
#   ('643',
#    Interval(838, 841, closed='left')): [('nurse',
#     Interval(831, 836, closed='left'))],
#   ('436',
#    Interval(852, 855, closed='left')): [('doctor',
#     Interval(844, 850, closed='left'))],
#   ('426',
#    Interval(877, 880, closed='left')): [('health technician',
#     Interval(858, 875, closed='left'))],
#   ('421',
#    Interval(897, 900, closed='left')): [('paramedic',
#     Interval(886, 895, closed='left'))],
#   ('56',
#    Interval(1268, 1270, closed='left')): [('health care personnel',
#     Interval(984, 1005, closed='left'))],
#   ('28',
#    Interval(1313, 1315, closed='left')): [('health care personnel',
#     Interval(984, 1005, closed='left'))]},
#  'a1_83005': {('five',
#    Interval(77, 81, closed='left')): [('Colombian bordering departments',
#     Interval(82, 113, closed='left'))],
#   ('54 percent',
#    Interval(133, 143, closed='left')): [('Venezuelans',
#     Interval(147, 158, closed='left'))],
#   ('8',
#    Interval(202, 203, closed='left')): [('migrants',
#     Interval(210, 218, closed='left'))],
#   ('10',
#    Interval(207, 209, closed='left')): [('migrants',
#     Interval(210, 218, closed='left'))],
#   ('6',
#    Interval(256, 257, closed='left')): [('pendular migrants',
#     Interval(264, 281, closed='left'))],
#   ('10',
#    Interval(261, 263, closed='left')): [('pendular migrants',
#     Interval(264, 281, closed='left'))],
#   ('55 percent',
#    Interval(374, 384, closed='left')): [('Venezuelans',
#     Interval(388, 399, closed='left'))],
#   ('half',
#    Interval(462, 466, closed='left')): [('surveyed',
#     Interval(474, 482, closed='left'))],
#   ('97 percent',
#    Interval(827, 837, closed='left')): [('people surveyed',
#     Interval(841, 856, closed='left'))]},
#  'a1_100228': {('11,322',
#    Interval(19, 25, closed='left')): [('movements',
#     Interval(26, 35, closed='left'))],
#   ('three',
#    Interval(47, 52, closed='left')): [('northeast states',
#     Interval(53, 69, closed='left'))],
#   ('8,653',
#    Interval(84, 89, closed='left')): [('arrivals',
#     Interval(95, 103, closed='left'))],
#   ('2, 669',
#    Interval(108, 114, closed='left')): [('departures',
#     Interval(115, 125, closed='left'))]},
#  'a3_241903': {('38 percent',
#    Interval(114, 124, closed='left')): [('imports volume',
#     Interval(86, 100, closed='left'))],
#   ('18 percent.',
#    Interval(257, 268, closed='left')): [('food imports volume',
#     Interval(204, 223, closed='left'))],
#   ('588,000',
#    Interval(347, 354, closed='left')): [('tons of wheat',
#     Interval(355, 368, closed='left'))],
#   ('25 percent',
#    Interval(852, 862, closed='left')): [('GDP',
#     Interval(833, 836, closed='left'))],
#   ('19 percent',
#    Interval(934, 944, closed='left')): [('GDP',
#     Interval(916, 919, closed='left'))]},
#  'a2_313446': {('Ninety-three percent',
#    Interval(72, 92, closed='left')): [('Rohingya household',
#     Interval(96, 114, closed='left'))],
#   ('98 percent',
#    Interval(125, 135, closed='left')): [('host community',
#     Interval(139, 153, closed='left'))],
#   ('two',
#    Interval(221, 224, closed='left')): [('populations',
#     Interval(225, 236, closed='left'))],
#   ('24 percent',
#    Interval(333, 343, closed='left')): [('Rohingya male household',
#     Interval(347, 370, closed='left'))],
#   ('6 percent',
#    Interval(460, 469, closed='left')): [('host community male household heads',
#     Interval(473, 508, closed='left'))]},
#  'a3_286910': {('2 × 2',
#    Interval(903, 908, closed='left')): [('meter area',
#     Interval(909, 919, closed='left'))]},
#  'a3_76946': {('10',
#    Interval(427, 429, closed='left')): [('Nigerian soldiers',
#     Interval(430, 447, closed='left'))],
#   ('9',
#    Interval(460, 461, closed='left')): [('Nigerian soldiers',
#     Interval(430, 447, closed='left'))]},
#  'a2a3_360171': {('15',
#    Interval(34, 36, closed='left')): [('Rohingya',
#     Interval(42, 50, closed='left'))],
#   ('three',
#    Interval(163, 168, closed='left')): [('Rohingya',
#     Interval(169, 177, closed='left'))],
#   ('two',
#    Interval(189, 192, closed='left')): [('women',
#     Interval(193, 198, closed='left'))],
#   ('ten',
#    Interval(402, 405, closed='left')): [('Rohingya',
#     Interval(406, 414, closed='left'))]},
#  'a1a2_85694': {('1,000',
#    Interval(623, 628, closed='left')): [('Warao indigenous community members',
#     Interval(629, 663, closed='left'))],
#   ('4', Interval(1516, 1517, closed='left')): []},
#  'a2_71399': {('2 million',
#    Interval(597, 606, closed='left')): [('people',
#     Interval(607, 613, closed='left'))]},
#  'a2_354625': {('3 million',
#    Interval(85, 94, closed='left')): [('people',
#     Interval(95, 101, closed='left'))],
#   ('half',
#    Interval(113, 117, closed='left')): [('people',
#     Interval(95, 101, closed='left'))],
#   ('1,000',
#    Interval(222, 227, closed='left')): [('U.N. trucks',
#     Interval(228, 239, closed='left'))],
#   ('three',
#    Interval(397, 402, closed='left')): [('months',
#     Interval(403, 409, closed='left'))]},
#  'a2_320172': {('14',
#    Interval(58, 60, closed='left')): [('Month-on-month (m-o-m)',
#     Interval(30, 52, closed='left')), ('governorates',
#     Interval(61, 73, closed='left'))],
#   ('43 percent',
#    Interval(178, 188, closed='left')): [('highest m-o-m',
#     Interval(152, 165, closed='left'))],
#   ('198,582',
#    Interval(226, 233, closed='left')): [('SYP',
#     Interval(222, 225, closed='left'))],
# ...
#     Interval(161, 209, closed='left')), ('NGN',
#     Interval(279, 282, closed='left'))],
#   ('one',
#    Interval(433, 436, closed='left')): [('girl',
#     Interval(437, 441, closed='left'))],
#   ('30%',
#    Interval(541, 544, closed='left')): [('households with at least one girl among their school-going children',
#     Interval(408, 475, closed='left'))],
#   ('(7%',
#    Interval(608, 611, closed='left')): [('households who reportedly only had boys attending school',
#     Interval(551, 607, closed='left'))],
#   ('6',
#    Interval(625, 626, closed='left')): [('assessed LGAs',
#     Interval(627, 640, closed='left'))],
#   ('673',
#    Interval(721, 724, closed='left')): [('NGN',
#     Interval(725, 728, closed='left'))],
#   ('829',
#    Interval(786, 789, closed='left')): [('NGN',
#     Interval(790, 793, closed='left'))]},
#  'a1a2_192685': {('five',
#    Interval(118, 122, closed='left')): [('children under the age',
#     Interval(92, 114, closed='left'))],
#   ('4.1 per cent',
#    Interval(206, 218, closed='left')): [('GAM',
#     Interval(222, 225, closed='left'))],
#   ('23',
#    Interval(242, 244, closed='left')): [('provinces',
#     Interval(245, 254, closed='left'))],
#   ('3',
#    Interval(302, 303, closed='left')): [('provinces',
#     Interval(304, 313, closed='left'))]},
#  'a1a2_48603': {('182,000',
#    Interval(194, 201, closed='left')): [('people',
#     Interval(202, 208, closed='left'))],
#   ('700,000',
#    Interval(487, 494, closed='left')): [('Venezuelans',
#     Interval(495, 506, closed='left'))],
#   ('(59%)',
#    Interval(507, 512, closed='left')): [('Venezuelans',
#     Interval(495, 506, closed='left'))],
#   ('500,000', Interval(565, 572, closed='left')): [],
#   ('(41%)', Interval(573, 578, closed='left')): [],
#   ('2,7 million',
#    Interval(641, 652, closed='left')): [('Venezuelan people',
#     Interval(653, 670, closed='left'))],
#   ('one',
#    Interval(754, 757, closed='left')): [('week',
#     Interval(758, 762, closed='left'))]},
#  'a1a3_295505': {},
#  'a3_363341': {('6 684',
#    Interval(138, 143, closed='left')): [('SYP',
#     Interval(144, 147, closed='left'))],
#   ('30',
#    Interval(186, 188, closed='left')): [('eggs',
#     Interval(189, 193, closed='left'))],
#   ('4 percent',
#    Interval(195, 204, closed='left')): [('m-om',
#     Interval(205, 209, closed='left'))],
#   ('11 percent',
#    Interval(272, 282, closed='left')): [('m-o-m',
#     Interval(292, 297, closed='left'))],
#   ('7 767',
#    Interval(340, 345, closed='left')): [('SYP a crate or pack 30 eggs',
#     Interval(346, 373, closed='left'))],
#   ('1 percent',
#    Interval(444, 453, closed='left')): [('m-o-m',
#     Interval(454, 459, closed='left'))],
#   ('7 600',
#    Interval(509, 514, closed='left')): [('SYP per a pack 30 eggs respectively .',
#     Interval(525, 562, closed='left'))],
#   ('6 980',
#    Interval(519, 524, closed='left')): [('SYP per a pack 30 eggs respectively .',
#     Interval(525, 562, closed='left'))]},
#  'a2_5757': {('one',
#    Interval(193, 196, closed='left')): [('mobile clinic',
#     Interval(197, 210, closed='left'))]},
#  'a1_62106': {('9,900',
#    Interval(307, 312, closed='left')): [('cases',
#     Interval(313, 318, closed='left'))],
#   ('6,700',
#    Interval(342, 347, closed='left')): [('cases',
#     Interval(313, 318, closed='left'))],
#   ('79',
#    Interval(374, 376, closed='left')): [('cases',
#     Interval(386, 391, closed='left'))],
#   ('2,800',
#    Interval(501, 506, closed='left')): [('cases',
#     Interval(507, 512, closed='left'))],
#   ('1,700',
#    Interval(536, 541, closed='left')): [('cases',
#     Interval(507, 512, closed='left')), ('conﬁrmed',
#     Interval(542, 550, closed='left'))],
#   ('286',
#    Interval(568, 571, closed='left')): [('cases',
#     Interval(507, 512, closed='left'))],
#   ('36,000',
#    Interval(665, 671, closed='left')): [('cases',
#     Interval(672, 677, closed='left'))],
#   ('414,000',
#    Interval(729, 736, closed='left')): [('cases',
#     Interval(737, 742, closed='left'))],
#   ('6,000',
#    Interval(814, 819, closed='left')): [('tuberculosis cases',
#     Interval(766, 784, closed='left'))],
#   ('13,000',
#    Interval(831, 837, closed='left')): [('tuberculosis cases',
#     Interval(766, 784, closed='left'))],
#   ('forty',
#    Interval(873, 878, closed='left')): [('years',
#     Interval(879, 884, closed='left'))]},
#  'a1_173902': {('15',
#    Interval(421, 423, closed='left')): [('children',
#     Interval(424, 432, closed='left'))],
#   ('six',
#    Interval(434, 437, closed='left')): [('girls',
#     Interval(438, 443, closed='left'))],
#   ('nine',
#    Interval(448, 452, closed='left')): [('boys',
#     Interval(453, 457, closed='left'))]},
#  'a2_306095': {},
#  'a3_24902': {('3,877',
#    Interval(146, 151, closed='left')): [('houses',
#     Interval(152, 158, closed='left'))],
#   ('18',
#    Interval(166, 168, closed='left')): [('states',
#     Interval(169, 175, closed='left'))],
#   ('23 per cent',
#    Interval(194, 205, closed='left')): [('internally displaced persons',
#     Interval(213, 241, closed='left'))],
#   ('70,000',
#    Interval(396, 402, closed='left')): [('IDP households settled in camps',
#     Interval(403, 434, closed='left'))],
#   ('88 %',
#    Interval(632, 636, closed='left')): [('internally displaced persons living outside of camp settings',
#     Interval(522, 582, closed='left'))],
#   ('one quarter',
#    Interval(686, 697, closed='left')): [('individuals',
#     Interval(715, 726, closed='left'))],
#   ('270,000',
#    Interval(707, 714, closed='left')): [('individuals',
#     Interval(715, 726, closed='left'))]},
#  'a2_215316': {('700,000',
#    Interval(10, 17, closed='left')): [('people',
#     Interval(18, 24, closed='left'))],
#   ('34',
#    Interval(28, 30, closed='left')): [('counties',
#     Interval(31, 39, closed='left'))],
#   ('90 percent',
#    Interval(79, 89, closed='left')): [('flood-affected population',
#     Interval(97, 122, closed='left'))]},
#  'a2_33790': {('1,000',
#    Interval(288, 293, closed='left')): [('dead',
#     Interval(294, 298, closed='left'))],
#   ('five',
#    Interval(482, 486, closed='left')): [('years',
#     Interval(487, 492, closed='left'))],
#   ('276',
#    Interval(838, 841, closed='left')): [('schoolgirls',
#     Interval(842, 853, closed='left'))]},
#  'a3_215291': {('6,143',
#    Interval(304, 309, closed='left')): [('children',
#     Interval(310, 318, closed='left'))],
#   ('80%',
#    Interval(410, 413, closed='left')): [('verified cases',
#     Interval(417, 431, closed='left'))],
#   ('4,910',
#    Interval(433, 438, closed='left')): [('verified cases',
#     Interval(417, 431, closed='left'))],
#   ('391',
#    Interval(479, 482, closed='left')): [('verified cases',
#     Interval(417, 431, closed='left'))],
#   ('172',
#    Interval(504, 507, closed='left')): [('verified cases',
#     Interval(417, 431, closed='left'))],
#   ('1,442',
#    Interval(525, 530, closed='left')): [('boys',
#     Interval(531, 535, closed='left'))],
#   ('53',
#    Interval(540, 542, closed='left')): [('girls',
#     Interval(543, 548, closed='left'))]},
#  'a3_248406': {('70 percent', Interval(298, 308, closed='left')): [],
#   ('38 percent', Interval(313, 323, closed='left')): [],
#   ('2 percent',
#    Interval(471, 480, closed='left')): [('proxy prevalence of chronic malnutrition(stunting)',
#     Interval(390, 440, closed='left'))],
#   ('2.2 million',
#    Interval(608, 619, closed='left')): [('children aged 6-59 months and pregnant and lactating women (PLW)',
#     Interval(620, 684, closed='left'))],
#   ('588',
#    Interval(745, 748, closed='left')): [('communities',
#     Interval(749, 760, closed='left'))],
#   ('42',
#    Interval(765, 767, closed='left')): [('sub-districts of northwest Syria',
#     Interval(768, 800, closed='left'))],
#   ('95 percent',
#    Interval(825, 835, closed='left')): [('population in need',
#     Interval(843, 861, closed='left'))],
#   ('9 percent',
#    Interval(865, 874, closed='left')): [('increase in coverage',
#     Interval(875, 895, closed='left'))]},
#  'a1_345410': {('1,298',
#    Interval(88, 93, closed='left')): [('individuals',
#     Interval(94, 105, closed='left'))],
#   ('3 per cent',
#    Interval(176, 186, closed='left')): [('individuals',
#     Interval(214, 225, closed='left'))],
#   ('1,336',
#    Interval(208, 213, closed='left')): [('individuals',
#     Interval(214, 225, closed='left'))]},
#  'a1_255434': {('940,000',
#    Interval(53, 60, closed='left')): [('people',
#     Interval(61, 67, closed='left'))],
#   ('194,000',
#    Interval(78, 85, closed='left')): [('women',
#     Interval(90, 95, closed='left'))],
#   ('566,000',
#    Interval(100, 107, closed='left')): [('children',
#     Interval(112, 120, closed='left'))],
#   ('2.7 million',
#    Interval(181, 192, closed='left')): [('people',
#     Interval(193, 199, closed='left'))],
#   ('four million',
#    Interval(235, 247, closed='left')): [('people',
#     Interval(248, 254, closed='left'))],
#   ('2.8 million',
#    Interval(280, 291, closed='left')): [('people',
#     Interval(248, 254, closed='left'))],
#   ('one',
#    Interval(643, 646, closed='left')): [('week',
#     Interval(647, 651, closed='left'))],
#   ('five',
#    Interval(685, 689, closed='left')): [('children',
#     Interval(690, 698, closed='left'))],
#   ('two',
#    Interval(816, 819, closed='left')): [('aid workers',
#     Interval(820, 831, closed='left'))]},
#  'a1_17111': {('1,542',
#    Interval(94, 99, closed='left')): [('individuals',
#     Interval(100, 111, closed='left'))],
#   ('11',
#    Interval(152, 154, closed='left')): [('resettlement States',
#     Interval(155, 174, closed='left'))],
#   ('930',
#    Interval(311, 314, closed='left')): [('individuals',
#     Interval(315, 326, closed='left'))],
#   ('248',
#    Interval(505, 508, closed='left')): [('individuals',
#     Interval(509, 520, closed='left'))],
#   ('245',
#    Interval(700, 703, closed='left')): [('individuals',
#     Interval(704, 715, closed='left'))]},
#  'a2_309932': {('23',
#    Interval(90, 92, closed='left')): [('PoEs',
#     Interval(93, 97, closed='left'))],
#   ('12',
#    Interval(154, 156, closed='left')): [('land borders',
#     Interval(140, 152, closed='left'))],
#   ('8',
#    Interval(181, 182, closed='left')): [('airports',
#     Interval(171, 179, closed='left'))],
#   ('(3',
#    Interval(201, 203, closed='left')): [('blue borders',
#     Interval(188, 200, closed='left'))],
#   ('19',
#    Interval(407, 409, closed='left')): [('PoEs',
#     Interval(417, 421, closed='left'))],
#   ('231',
#    Interval(413, 416, closed='left')): [('PoEs',
#     Interval(417, 421, closed='left'))],
#   ('10',
#    Interval(566, 568, closed='left')): [('PoEs',
#     Interval(569, 573, closed='left'))],
#   ('nine',
#    Interval(598, 602, closed='left')): [('PoEs',
#     Interval(569, 573, closed='left'))],
#   ('three',
#    Interval(631, 636, closed='left')): [('PoEs',
#     Interval(569, 573, closed='left'))],
#   ('one',
#    Interval(659, 662, closed='left')): [('PoEs',
#     Interval(569, 573, closed='left'))]},
#  'a3_179161': {('19 percent',
#    Interval(104, 114, closed='left')): [('prevalence of  chronic malnutrition among children aged 6-59 months',
#     Interval(21, 88, closed='left'))],
#   ('19 percent to 33 percent',
#    Interval(104, 128, closed='left')): [('prevalence of  chronic malnutrition among children aged 6-59 months',
#     Interval(21, 88, closed='left'))],
#   ('33 percent',
#    Interval(118, 128, closed='left')): [('prevalence of  chronic malnutrition among children aged 6-59 months',
#     Interval(21, 88, closed='left'))],
#   ('35percent',
#    Interval(130, 139, closed='left')): [('prevalence of  chronic malnutrition among children aged 6-59 months',
#     Interval(21, 88, closed='left'))],
#   ('31percent',
#    Interval(150, 159, closed='left')): [('prevalence of  chronic malnutrition among children aged 6-59 months',
#     Interval(21, 88, closed='left'))],
#   ('1 percent',
#    Interval(265, 274, closed='left')): [('prevalence of acute malnutrition',
#     Interval(217, 249, closed='left'))],
#   ('1 percent to 2 percent',
#    Interval(265, 287, closed='left')): [('prevalence of acute malnutrition',
#     Interval(217, 249, closed='left'))],
#   ('2 percent',
#    Interval(278, 287, closed='left')): [('prevalence of acute malnutrition',
#     Interval(217, 249, closed='left'))],
#   ('11 percent',
#    Interval(417, 427, closed='left')): [('prevalence of acute malnutrition across northwest Syria',
#     Interval(355, 410, closed='left'))],
#   ('4 percent',
#    Interval(622, 631, closed='left')): [('prevalence  of  acute  malnutrition',
#     Interval(511, 546, closed='left'))],
#   ('4 percent vs. 1 percent',
#    Interval(622, 645, closed='left')): [('prevalence  of  acute  malnutrition',
#     Interval(511, 546, closed='left'))],
#   ('1 percent',
#    Interval(636, 645, closed='left')): [('prevalence  of  acute  malnutrition',
#     Interval(511, 546, closed='left'))],
#   ('20 percent',
#    Interval(656, 666, closed='left')): [('prevalence  of  acute  malnutrition',
#     Interval(511, 546, closed='left'))],
#   ('20 percent vs. 2 percent',
#    Interval(656, 680, closed='left')): [('prevalence  of  acute  malnutrition',
#     Interval(511, 546, closed='left'))],
#   ('2 percent',
#    Interval(671, 680, closed='left')): [('prevalence  of  acute  malnutrition',
#     Interval(511, 546, closed='left'))]},
#  'a2a3_361401': {('5',
#    Interval(561, 562, closed='left')): [('children',
#     Interval(546, 554, closed='left'))]},
#  'a2_78512': {('28',
#    Interval(5, 7, closed='left')): [('people',
#     Interval(8, 14, closed='left'))],
#   ('14',
#    Interval(60, 62, closed='left')): [('casualties',
#     Interval(63, 73, closed='left'))],
#   ('7',
#    Interval(87, 88, closed='left')): [('individuals',
#     Interval(89, 100, closed='left'))],
#   ('52',
#    Interval(153, 155, closed='left')): [('houses',
#     Interval(156, 162, closed='left'))],
#   ('3,590',
#    Interval(296, 301, closed='left')): [('children',
#     Interval(302, 310, closed='left'))],
#   ('1,126',
#    Interval(312, 317, closed='left')): [('adult men',
#     Interval(318, 327, closed='left'))],
#   ('1,510',
#    Interval(329, 334, closed='left')): [('adult women',
#     Interval(335, 346, closed='left'))],
#   ('193',
#    Interval(351, 354, closed='left')): [('elderly persons',
#     Interval(355, 370, closed='left'))],
#   ('71 per cent',
#    Interval(377, 388, closed='left')): [('displaced population',
#     Interval(396, 416, closed='left'))],
#   ('29 per cent', Interval(524, 535, closed='left')): []},
#  'a2_187638': {('70',
#    Interval(9, 11, closed='left')): [('health workers',
#     Interval(12, 26, closed='left'))],
#   ('two',
#    Interval(143, 146, closed='left')): [('Health Care Facility/Maternal Child Health Centres',
#     Interval(147, 197, closed='left'))],
#   ('10',
#    Interval(476, 478, closed='left')): [('persons',
#     Interval(479, 486, closed='left'))],
#   ('Two',
#    Interval(704, 707, closed='left')): [('overcrowded IDP sites',
#     Interval(708, 729, closed='left'))]},
#  'a2_259957': {('25',
#    Interval(414, 416, closed='left')): [('counties',
#     Interval(417, 425, closed='left'))],
#   ('193',
#    Interval(613, 616, closed='left')): [('health facilities',
#     Interval(617, 634, closed='left'))],
#   ('15,000',
#    Interval(911, 917, closed='left')): [('target population',
#     Interval(890, 907, closed='left')), ('people',
#     Interval(918, 924, closed='left'))]},
#  'a2_186732': {('200',
#    Interval(27, 30, closed='left')): [('NFI kits',
#     Interval(31, 39, closed='left'))],
#   ('939',
#    Interval(94, 97, closed='left')): [('individuals',
#     Interval(98, 109, closed='left'))],
#   ('454',
#    Interval(111, 114, closed='left')): [('females',
#     Interval(115, 122, closed='left'))],
#   ('485',
#    Interval(124, 127, closed='left')): [('males',
#     Interval(128, 133, closed='left'))],
#   ('4,557',
#    Interval(190, 195, closed='left')): [('households',
#     Interval(196, 206, closed='left'))],
#   ('1,595',
#    Interval(362, 367, closed='left')): [('households',
#     Interval(368, 378, closed='left'))],
#   ('2,088',
#    Interval(412, 417, closed='left')): [('households',
#     Interval(368, 378, closed='left'))],
#   ('874',
#    Interval(456, 459, closed='left')): [('households',
#     Interval(460, 470, closed='left'))],
#   ('48',
#    Interval(574, 576, closed='left')): [('households',
#     Interval(577, 587, closed='left'))]}}
